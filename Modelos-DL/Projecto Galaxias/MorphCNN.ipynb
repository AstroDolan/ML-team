# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import os
import random
import time
import matplotlib.pyplot as plt

from skimage.transform import resize
from tqdm import tqdm # progress which the model
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# 2026-01-14 14:19:37.059397: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/djara/miniconda3/envs/tf216/lib/python3.11/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
df = pd.read_csv('../GalaxyZoo/training_solutions_rev1.csv')
print("El dataset tiene " + str(df.shape[0]) + " filas y " + str(df.shape[1]) + " columnas.")
df.head()
# Out:
# El dataset tiene 61578 filas y 38 columnas.
#    GalaxyID  Class1.1  Class1.2  Class1.3  Class2.1  Class2.2  Class3.1  \
# 0    100008  0.383147  0.616853  0.000000  0.000000  0.616853  0.038452
# 1    100023  0.327001  0.663777  0.009222  0.031178  0.632599  0.467370
# 2    100053  0.765717  0.177352  0.056931  0.000000  0.177352  0.000000
# 3    100078  0.693377  0.238564  0.068059  0.000000  0.238564  0.109493
# 4    100090  0.933839  0.000000  0.066161  0.000000  0.000000  0.000000
#
#    Class3.2  Class4.1  Class4.2  ...  Class9.3  Class10.1  Class10.2  \
# 0  0.578401  0.418398  0.198455  ...  0.000000   0.279952   0.138445
# 1  0.165229  0.591328  0.041271  ...  0.018764   0.000000   0.131378
# 2  0.177352  0.000000  0.177352  ...  0.000000   0.000000   0.000000
# 3  0.129071  0.189098  0.049466  ...  0.000000   0.094549   0.000000
# 4  0.000000  0.000000  0.000000  ...  0.000000   0.000000   0.000000
#
#    Class10.3  Class11.1  Class11.2  Class11.3  Class11.4  Class11.5  Class11.6
# 0   0.000000   0.000000   0.092886        0.0        0.0        0.0   0.325512
# 1   0.459950   0.000000   0.591328        0.0        0.0        0.0   0.000000
# 2   0.000000   0.000000   0.000000        0.0        0.0        0.0   0.000000
# 3   0.094549   0.189098   0.000000        0.0        0.0        0.0   0.000000
# 4   0.000000   0.000000   0.000000        0.0        0.0        0.0   0.000000
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Separamos entre training y testing

# %%
df_train, df_test = train_test_split(df[:60000], test_size=0.2, random_state=42)
print("El conjunto de entrenamiento tiene forma", df_train.shape)
print("El conjunto de prueba tiene forma", df_test.shape)
# Out:
# El conjunto de entrenamiento tiene forma (48000, 38)
# El conjunto de prueba tiene forma (12000, 38)

# %%
df_train.describe()
# Out:
#             GalaxyID      Class1.1      Class1.2      Class1.3      Class2.1  \
# count   48000.000000  48000.000000  48000.000000  48000.000000  48000.000000
# mean   538143.107917      0.432935      0.541868      0.025197      0.105937
# std    251940.632381      0.283285      0.296177      0.037490      0.211966
# min    100008.000000      0.000000      0.000000      0.000000      0.000000
# 25%    321855.000000      0.176687      0.281082      0.000000      0.000000
# 50%    538293.500000      0.417305      0.558762      0.014958      0.000000
# 75%    756402.250000      0.678986      0.810756      0.034321      0.085075
# max    976566.000000      1.000000      1.000000      0.935147      1.000000
#
#            Class2.2      Class3.1      Class3.2      Class4.1      Class4.2  \
# count  48000.000000  48000.000000  48000.000000  48000.000000  48000.000000
# mean       0.435931      0.102922      0.333010      0.215219      0.220713
# std        0.301536      0.178280      0.247543      0.284932      0.180176
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.168404      0.000000      0.122303      0.000000      0.072765
# 50%        0.395424      0.000000      0.288853      0.092417      0.183329
# 75%        0.694376      0.134237      0.516485      0.329996      0.339593
# max        1.000000      1.000000      1.000000      1.000000      0.957937
#
#        ...      Class9.3     Class10.1     Class10.2     Class10.3  \
# count  ...  48000.000000  48000.000000  48000.000000  48000.000000
# mean   ...      0.032840      0.091422      0.083896      0.039901
# std    ...      0.098344      0.144634      0.139775      0.099281
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.146307      0.127016      0.030787
# max    ...      0.901991      0.949733      0.877393      0.974348
#
#           Class11.1     Class11.2     Class11.3     Class11.4     Class11.5  \
# count  48000.000000  48000.000000  48000.000000  48000.000000  48000.000000
# mean       0.015296      0.094296      0.017537      0.007502      0.006989
# std        0.051666      0.193853      0.067327      0.037540      0.037281
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.098325      0.000000      0.000000      0.000000
# max        0.872332      1.000000      0.975913      0.957000      0.938881
#
#           Class11.6
# count  48000.000000
# mean       0.073599
# std        0.107285
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.128729
# max        0.753082
#
# [8 rows x 38 columns]

# %% [markdown]
# ## Exploratory Data Analysis para las imagenes

# %%
trainPath = '../GalaxyZoo/images_training_rev1/'
testPath = '../GalaxyZoo/images_test_rev1/'

# %%
def plot_random_galaxy(path, sample = 5):
    random_image=random.sample(os.listdir(path),sample) #Lista todo los archivos en el directorio y selecciona 'sample' aleatoriamente
 
    plt.figure(figsize=(16,5))
    for i in range(sample):
        
        plt.subplot(1,sample,i+1) #
        img=tf.io.read_file(os.path.join(path,random_image[i])) # construye ruta completa (ej: 'GalaxyZoo/images_training_rev1/123.jpg' 
        img=tf.io.decode_image(img)
        plt.imshow(img)
        plt.title(f'Class: {random_image[i]}\nShape: {img.shape}')
        plt.axis(False)

# %%
plot_random_galaxy(trainPath)
# Out:
# 2026-01-14 14:19:40.768768: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-14 14:19:40.886080: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-14 14:19:40.886156: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-14 14:19:40.888121: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-14 14:19:40.888218: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-14 14:19:40.888255: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-14 14:19:41.060243: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-14 14:19:41.060317: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-14 14:19:41.060328: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-01-14 14:19:41.060385: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-14 14:19:41.060827: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5562 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
plot_random_galaxy(testPath)

# %%
ORIG_SHAPE = (424,424)
CROP_SIZE = (256,256)
IMG_SHAPE = (64,64)

tt = time.time()
def get_image(path, x1, y1, shape, crop_size): #Lee la imagen desde el path, la recorta y la redimensiona
    # Usar TensorFlow para leer la imagen (igual que en plot_random_galaxy que funciona)
    img = tf.io.read_file(path)
    img = tf.io.decode_image(img, channels=3)
    img = tf.cast(img, tf.float32)  # Convertir a float32
    
    # Recortar
    img = img[x1:x1+crop_size[0], y1:y1+crop_size[1]]
    
    # Redimensionar
    img = tf.image.resize(img, shape)
    
    # Normalizar (tf.io.decode_image devuelve 0-255 para JPG)
    img = img / 255.0
    
    return img.numpy()
    
def get_all_images(dataframe, shape=IMG_SHAPE, crop_size=CROP_SIZE): #Obtiene todas las imágenes del dataframe, las recorta y redimensiona
    x1 = (ORIG_SHAPE[0]-CROP_SIZE[0])//2
    y1 = (ORIG_SHAPE[1]-CROP_SIZE[1])//2
   
    sel = dataframe.values
    ids = sel[:,0].astype(int).astype(str)
    y_batch = sel[:,1:]
    x_batch = []
    for i in tqdm(ids):
        x = get_image('../GalaxyZoo/images_training_rev1/'+i+'.jpg', x1, y1, shape=shape, crop_size=crop_size)
        x_batch.append(x)
    x_batch = np.array(x_batch)
    return x_batch, y_batch
        
X_train, y_train = get_all_images(df_train)
X_test, y_test = get_all_images(df_test)
print('Procesado en: ', (time.time()-tt)/60, " minutos")
# Out:
# 100%|██████████| 48000/48000 [01:58<00:00, 403.55it/s]
# 100%|██████████| 12000/12000 [00:28<00:00, 416.12it/s]
# Procesado en:  2.4810046553611755  minutos

# %%
print("Forma del train: ",X_train.shape)
print("Forma del train: ",X_test.shape)
# Out:
# Forma del train:  (48000, 64, 64, 3)
# Forma del train:  (12000, 64, 64, 3)

# %% [markdown]
# ## Creamos la red neuronal

# %%
# Verificar disponibilidad de GPU
print("=" * 60)
print("VERIFICACIÓN DE GPU")
print("=" * 60)

# Listar dispositivos
gpus = tf.config.list_physical_devices('GPU')
cpus = tf.config.list_physical_devices('CPU')

print(f"\n✓ GPUs disponibles: {len(gpus)}")
for gpu in gpus:
    print(f"  - {gpu}")
    
print(f"\n✓ CPUs disponibles: {len(cpus)}")
for cpu in cpus:
    print(f"  - {cpu}")

# Verificar si CUDA está disponible
print(f"\n✓ TensorFlow versión: {tf.__version__}")
print(f"✓ Built with CUDA: {tf.test.is_built_with_cuda()}")

# Habilitar crecimiento de memoria GPU (evita OOM)
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("\n✓ Crecimiento de memoria GPU habilitado")
    except RuntimeError as e:
        print(f"\n✗ Error configurando memoria: {e}")
else:
    print("\n⚠ ADVERTENCIA: No se detectaron GPUs. El entrenamiento será MÁS LENTO.")

print("=" * 60 + "\n")
# Out:
# ============================================================
# VERIFICACIÓN DE GPU
# ============================================================
#
# ✓ GPUs disponibles: 1
#   - PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
#
# ✓ CPUs disponibles: 1
#   - PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')
#
# ✓ TensorFlow versión: 2.16.1
# ✓ Built with CUDA: True
#
# ✗ Error configurando memoria: Physical devices cannot be modified after being initialized
# ============================================================

# %%
# Estrategia de distribución para GPU
# Usar la estrategia por defecto de TensorFlow para evitar mezclar objetos de estrategia
strategy = tf.distribute.get_strategy()
if gpus:
    print(f"Usando {len(gpus)} GPU(s) para entrenamiento")
else:
    print("Usando CPU para entrenamiento")

print(f"Número de réplicas: {strategy.num_replicas_in_sync}\n")
# Out:
# Usando 1 GPU(s) para entrenamiento
# Número de réplicas: 1

# %%
import tensorflow as tf
import numpy as np
import time
from tensorflow.keras import layers, models
from tensorflow.keras.models import Model
from tensorflow.keras import Input  # <--- ESTA ES LA IMPORTACIÓN QUE FALTABA
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.svm import LinearSVR
from sklearn.multioutput import MultiOutputRegressor

def root_mean_squared_error(y_true, y_pred):
    # Usar operaciones de TensorFlow para mayor compatibilidad (evita mezclar keras y tf.keras)
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),  # Rotación aleatoria del 20%
    layers.RandomZoom(0.1),
])

opt = tf.keras.optimizers.Adam(learning_rate=0.001)
# Crear el modelo dentro de la estrategia de distribución
with strategy.scope():
    # A. Definimos la entrada explícitamente (Esto elimina el error de "input not defined")
    inputs = Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], 3), name='input_image')
    
    # B. Data Augmentation
    x = data_augmentation(inputs)
    
    # C. Bloques Convolucionales (Conectamos x con la capa anterior)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)

    features = layers.GlobalAveragePooling2D(name='feature_layer')(x)
    
    x = layers.Dense(256, activation='relu')(features)
    x = layers.Dropout(0.5)(x)

    x = layers.Dense(37, activation='relu')(x)

    # D. Capa de Características (LE PONEMOS NOMBRE PARA ENCONTRARLA FÁCIL)
    # Esta variable 'features' guarda el tensor de 256 valores
    
    # E. Capa de Salida (Solo para entrenar la CNN primero)
    outputs = layers.Dense(37, activation='sigmoid', name='output_layer')(x)

    # F. Crear el Modelo
    model = Model(inputs=inputs, outputs=outputs, name="Functional_CNN")

    # Compilación
    model.compile(optimizer=opt,
                  loss=root_mean_squared_error,
                  metrics=['mse'])
                  
model.summary()

reduce_lr = ReduceLROnPlateau(monitor='val_mse', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
# Detiene el entrenamiento si no mejora para evitar overfitting
early_stop = EarlyStopping(monitor='val_mse', mode='min', patience=10, restore_best_weights=True, verbose=1)
# Out:
# Model: "Functional_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 64, 64, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ feature_layer                   │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 37)             │         9,509 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 37)             │         1,406 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 449,315 (1.71 MB)
#  Trainable params: 448,419 (1.71 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
print("\n" + "="*60)
print("INICIANDO ENTRENAMIENTO")
print("="*60)

t = time.time()
ep = 30

# Entrenar con callbacks y monitoreo
history = model.fit(
    X_train, y_train, 
    epochs=ep, 
    batch_size=256,  # Aumentar batch_size también ayuda a GPU
    validation_data=(X_test, y_test),
    callbacks=[reduce_lr, early_stop],
    verbose=1  # Mostrar progreso detallado
)

tiempo_entrenamiento = time.time() - t
print(f"\n✓ Tiempo de entrenamiento: {tiempo_entrenamiento:.2f} segundos")
print(f"✓ Tiempo promedio por epoch: {tiempo_entrenamiento/ep:.2f} segundos")
print(f"\n✓ Tiempo de entrenamiento: {tiempo_entrenamiento/60:.2f} minutos")
print(f"✓ Tiempo promedio por epoch: {tiempo_entrenamiento/(ep*60):.2f} minutos")
print("="*60)
# Out:
# ============================================================
# INICIANDO ENTRENAMIENTO
# ============================================================
# 2026-01-14 14:22:12.555394: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 2359296000 exceeds 10% of free system memory.
# 2026-01-14 14:22:14.660480: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 2359296000 exceeds 10% of free system memory.
# Epoch 1/30
# 2026-01-14 14:22:18.984292: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
#   2/188 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 0.4640 - mse: 0.2155
# 2026-01-14 14:22:21.067913: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.39GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 28s 119ms/step - loss: 0.1804 - mse: 0.0374 - val_loss: 0.1706 - val_mse: 0.0291 - learning_rate: 0.0010
# Epoch 2/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - loss: 0.1261 - mse: 0.0159 - val_loss: 0.2275 - val_mse: 0.0518 - learning_rate: 0.0010
# Epoch 3/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - loss: 0.1170 - mse: 0.0137 - val_loss: 0.2258 - val_mse: 0.0510 - learning_rate: 0.0010
# Epoch 4/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - loss: 0.1120 - mse: 0.0126 - val_loss: 0.1280 - val_mse: 0.0164 - learning_rate: 0.0010
# Epoch 5/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - loss: 0.1086 - mse: 0.0118 - val_loss: 0.1133 - val_mse: 0.0128 - learning_rate: 0.0010
# Epoch 6/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.1064 - mse: 0.0113 - val_loss: 0.1205 - val_mse: 0.0145 - learning_rate: 0.0010
# Epoch 7/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 98ms/step - loss: 0.1050 - mse: 0.0110 - val_loss: 0.1055 - val_mse: 0.0111 - learning_rate: 0.0010
# Epoch 8/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.1032 - mse: 0.0107 - val_loss: 0.1149 - val_mse: 0.0132 - learning_rate: 0.0010
# Epoch 9/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - loss: 0.1025 - mse: 0.0105 - val_loss: 0.1187 - val_mse: 0.0141 - learning_rate: 0.0010
# Epoch 10/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.1021 - mse: 0.0104
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - loss: 0.1015 - mse: 0.0103 - val_loss: 0.1132 - val_mse: 0.0128 - learning_rate: 0.0010
# Epoch 11/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - loss: 0.0995 - mse: 0.0099 - val_loss: 0.1014 - val_mse: 0.0103 - learning_rate: 5.0000e-04
# Epoch 12/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - loss: 0.0989 - mse: 0.0098 - val_loss: 0.1047 - val_mse: 0.0110 - learning_rate: 5.0000e-04
# Epoch 13/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - loss: 0.0983 - mse: 0.0097 - val_loss: 0.0998 - val_mse: 0.0100 - learning_rate: 5.0000e-04
# Epoch 14/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - loss: 0.0982 - mse: 0.0096 - val_loss: 0.0996 - val_mse: 0.0099 - learning_rate: 5.0000e-04
# Epoch 15/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - loss: 0.0977 - mse: 0.0096 - val_loss: 0.0999 - val_mse: 0.0100 - learning_rate: 5.0000e-04
# Epoch 16/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - loss: 0.0974 - mse: 0.0095 - val_loss: 0.0975 - val_mse: 0.0095 - learning_rate: 5.0000e-04
# Epoch 17/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - loss: 0.0970 - mse: 0.0094 - val_loss: 0.1054 - val_mse: 0.0111 - learning_rate: 5.0000e-04
# Epoch 18/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - loss: 0.0967 - mse: 0.0094 - val_loss: 0.1018 - val_mse: 0.0104 - learning_rate: 5.0000e-04
# Epoch 19/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0963 - mse: 0.0093
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - loss: 0.0962 - mse: 0.0093 - val_loss: 0.0989 - val_mse: 0.0098 - learning_rate: 5.0000e-04
# Epoch 20/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.0953 - mse: 0.0091 - val_loss: 0.0968 - val_mse: 0.0094 - learning_rate: 2.5000e-04
# Epoch 21/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - loss: 0.0950 - mse: 0.0090 - val_loss: 0.0953 - val_mse: 0.0091 - learning_rate: 2.5000e-04
# Epoch 22/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - loss: 0.0949 - mse: 0.0090 - val_loss: 0.0997 - val_mse: 0.0099 - learning_rate: 2.5000e-04
# Epoch 23/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - loss: 0.0947 - mse: 0.0090 - val_loss: 0.0987 - val_mse: 0.0098 - learning_rate: 2.5000e-04
# Epoch 24/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0945 - mse: 0.0089
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 101ms/step - loss: 0.0944 - mse: 0.0089 - val_loss: 0.0988 - val_mse: 0.0098 - learning_rate: 2.5000e-04
# Epoch 25/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 0.0940 - mse: 0.0088 - val_loss: 0.0983 - val_mse: 0.0097 - learning_rate: 1.2500e-04
# Epoch 26/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - loss: 0.0939 - mse: 0.0088 - val_loss: 0.0934 - val_mse: 0.0087 - learning_rate: 1.2500e-04
# Epoch 27/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - loss: 0.0937 - mse: 0.0088 - val_loss: 0.0940 - val_mse: 0.0088 - learning_rate: 1.2500e-04
# Epoch 28/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - loss: 0.0935 - mse: 0.0087 - val_loss: 0.0944 - val_mse: 0.0089 - learning_rate: 1.2500e-04
# Epoch 29/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0933 - mse: 0.0087
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - loss: 0.0933 - mse: 0.0087 - val_loss: 0.0944 - val_mse: 0.0089 - learning_rate: 1.2500e-04
# Epoch 30/30
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - loss: 0.0931 - mse: 0.0087 - val_loss: 0.0938 - val_mse: 0.0088 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 26.
#
# ✓ Tiempo de entrenamiento: 607.94 segundos
# ✓ Tiempo promedio por epoch: 20.26 segundos
#
# ✓ Tiempo de entrenamiento: 10.13 minutos
# ✓ Tiempo promedio por epoch: 0.34 minutos
# ============================================================

# %% [markdown]
# # CNN: $MSE=0.0098$

# %%
import os

# Definir carpeta
save_dir = 'modelos_guardados'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

print("Guardando CNN Vanilla...")

# Solo esta línea es necesaria
model.save(os.path.join(save_dir, 'galaxy_cnn_vanilla.keras'))

print(f"✓ Modelo guardado exitosamente en: {save_dir}/galaxy_cnn_vanilla.keras")
# Out:
# Guardando CNN Vanilla...
# ✓ Modelo guardado exitosamente en: modelos_guardados/galaxy_cnn_vanilla.keras

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from skimage.transform import resize

def predict_random_galaxy(model, X_data, y_data, data_path, num_samples=3):
    """
    Visualiza predicciones del modelo en imágenes random
    
    Args:
        model: Modelo entrenado
        X_data: Datos de imágenes procesadas (train o test)
        y_data: Etiquetas reales (train o test)
        data_path: Ruta de las imágenes originales
        num_samples: Número de muestras a visualizar
    """
    
    # Seleccionar índices random
    random_indices = random.sample(range(len(X_data)), num_samples)
    
    fig, axes = plt.subplots(num_samples, 2, figsize=(12, 4*num_samples))
    
    if num_samples == 1:
        axes = [axes]
    
    for idx, random_idx in enumerate(random_indices):
        # Obtener imagen procesada y etiqueta real
        img_processed = X_data[random_idx]
        y_real = y_data[random_idx]
        
        # Hacer predicción
        y_pred = model.predict(np.expand_dims(img_processed, axis=0), verbose=0)[0]
        
        # DEBUG: Verificar valores de la imagen
        print(f"\nDEBUG Muestra {idx+1}:")
        print(f"  Min valor imagen: {img_processed.min():.4f}")
        print(f"  Max valor imagen: {img_processed.max():.4f}")
        print(f"  Shape imagen: {img_processed.shape}")
        
        # Mostrar imagen procesada (izquierda) - Asegurar que se muestre correctamente
        # vmin y vmax garantizan que matplotlib interprete bien los valores normalizados
        axes[idx][0].imshow(img_processed, vmin=0, vmax=1, cmap='viridis')
        axes[idx][0].set_title(f'Imagen Procesada (64x64)\nÍndice: {random_idx}')
        axes[idx][0].axis('off')
        
        # Mostrar gráfico de predicciones vs reales (derecha)
        x_pos = np.arange(len(y_real))
        width = 0.35
        
        axes[idx][1].bar(x_pos - width/2, y_real, width, label='Real', alpha=0.8)
        axes[idx][1].bar(x_pos + width/2, y_pred, width, label='Predicción', alpha=0.8)
        axes[idx][1].set_xlabel('Clase')
        axes[idx][1].set_ylabel('Probabilidad')
        axes[idx][1].set_title(f'Comparación: Real vs Predicción')
        axes[idx][1].legend()
        axes[idx][1].set_ylim([0, 1])
        axes[idx][1].grid(axis='y', alpha=0.3)
        
        # Imprimir información detallada
        print(f"\n{'='*60}")
        print(f"Muestra {idx+1} - Índice: {random_idx}")
        print(f"{'='*60}")
        print(f"Clases con probabilidad real > 0.5:")
        for i, prob in enumerate(y_real):
            if prob > 0.5:
                print(f"  Clase {i}: {prob:.4f}")
        
        print(f"\nClases con probabilidad predicha > 0.5:")
        for i, prob in enumerate(y_pred):
            if prob > 0.5:
                print(f"  Clase {i}: {prob:.4f}")
        
        # Calcular accuracy por muestra
        accuracy = np.mean((y_pred > 0.5) == (y_real > 0.5))
        print(f"\nAccuracy en esta muestra: {accuracy*100:.2f}%")
    
    plt.tight_layout()
    plt.show()

# ============================================
# USAR LA FUNCIÓN
# ============================================

# Opción 1: Predecir en imágenes de TRAINING
print("PREDICCIONES EN CONJUNTO DE TRAINING")
predict_random_galaxy(model, X_train, y_train, trainPath, num_samples=3)

# Opción 2: Predecir en imágenes de TEST
print("\n\nPREDICCIONES EN CONJUNTO DE TEST")
predict_random_galaxy(model, X_test, y_test, testPath, num_samples=3)

# Opción 3: Una sola muestra específica
print("\n\nUNA SOLA MUESTRA")
predict_random_galaxy(model, X_test, y_test, testPath, num_samples=1)
# Out:
# PREDICCIONES EN CONJUNTO DE TRAINING
#
# DEBUG Muestra 1:
#   Min valor imagen: 0.0000
#   Max valor imagen: 0.8627
#   Shape imagen: (64, 64, 3)
#
# ============================================================
# Muestra 1 - Índice: 42425
# ============================================================
# Clases con probabilidad real > 0.5:
#   Clase 0: 0.8114
#   Clase 14: 0.8665
#   Clase 16: 0.7641
#
# Clases con probabilidad predicha > 0.5:
#   Clase 0: 0.6919
#   Clase 14: 0.8729
#   Clase 16: 0.6318
#
# Accuracy en esta muestra: 100.00%
#
# DEBUG Muestra 2:
#   Min valor imagen: 0.0000
#   Max valor imagen: 0.9892
#   Shape imagen: (64, 64, 3)
#
# ============================================================
# Muestra 2 - Índice: 43601
# ============================================================
# Clases con probabilidad real > 0.5:
#   Clase 1: 0.9456
#   Clase 4: 0.5429
#   Clase 13: 0.9865
#   Clase 23: 0.8874
#
# Clases con probabilidad predicha > 0.5:
#   Clase 1: 0.9261
#   Clase 4: 0.5236
#   Clase 13: 0.8617
#   Clase 23: 0.5619
#
# Accuracy en esta muestra: 100.00%
#
# DEBUG Muestra 3:
#   Min valor imagen: 0.0000
#   Max valor imagen: 0.8824
#   Shape imagen: (64, 64, 3)
#
# ============================================================
# Muestra 3 - Índice: 32475
# ============================================================
# Clases con probabilidad real > 0.5:
#   Clase 1: 0.7161
#   Clase 4: 0.6533
#   Clase 14: 0.6436
#
# Clases con probabilidad predicha > 0.5:
#   Clase 1: 0.6954
#   Clase 4: 0.6943
#   Clase 5: 0.5672
#   Clase 14: 0.7254
#
# Accuracy en esta muestra: 97.30%
# PREDICCIONES EN CONJUNTO DE TEST
#
# DEBUG Muestra 1:
#   Min valor imagen: 0.0000
#   Max valor imagen: 0.8127
#   Shape imagen: (64, 64, 3)
#
# ============================================================
# Muestra 1 - Índice: 11862
# ============================================================
# Clases con probabilidad real > 0.5:
#   Clase 0: 0.7952
#   Clase 14: 0.9540
#   Clase 15: 0.7419
#
# Clases con probabilidad predicha > 0.5:
#   Clase 0: 0.7532
#   Clase 14: 0.8764
#   Clase 15: 0.6421
#
# Accuracy en esta muestra: 100.00%
#
# DEBUG Muestra 2:
#   Min valor imagen: 0.0000
#   Max valor imagen: 0.6314
#   Shape imagen: (64, 64, 3)
#
# ============================================================
# Muestra 2 - Índice: 8279
# ============================================================
# Clases con probabilidad real > 0.5:
#   Clase 1: 0.8825
#   Clase 4: 0.8825
#   Clase 6: 0.8409
#   Clase 7: 0.6442
#   Clase 10: 0.6798
#   Clase 13: 0.7671
#
# Clases con probabilidad predicha > 0.5:
#   Clase 1: 0.8466
#   Clase 4: 0.8178
#   Clase 6: 0.7109
#   Clase 7: 0.5722
#   Clase 10: 0.5036
#   Clase 14: 0.6888
#
# Accuracy en esta muestra: 94.59%
#
# DEBUG Muestra 3:
#   Min valor imagen: 0.0000
#   Max valor imagen: 0.6010
#   Shape imagen: (64, 64, 3)
#
# ============================================================
# Muestra 3 - Índice: 7119
# ============================================================
# Clases con probabilidad real > 0.5:
#   Clase 1: 0.6785
#   Clase 4: 0.6785
#   Clase 6: 0.6785
#   Clase 8: 0.6785
#   Clase 14: 0.6212
#
# Clases con probabilidad predicha > 0.5:
#   Clase 1: 0.6803
#   Clase 4: 0.6748
#   Clase 6: 0.5972
#   Clase 14: 0.7474
#
# Accuracy en esta muestra: 97.30%
# UNA SOLA MUESTRA
#
# DEBUG Muestra 1:
#   Min valor imagen: 0.0000
#   Max valor imagen: 0.8686
#   Shape imagen: (64, 64, 3)
#
# ============================================================
# Muestra 1 - Índice: 10579
# ============================================================
# Clases con probabilidad real > 0.5:
#   Clase 1: 0.7315
#   Clase 4: 0.7315
#   Clase 7: 0.5255
#   Clase 11: 0.5935
#   Clase 14: 0.8534
#
# Clases con probabilidad predicha > 0.5:
#   Clase 1: 0.5718
#   Clase 4: 0.5258
#   Clase 14: 0.6519
#
# Accuracy en esta muestra: 94.59%
