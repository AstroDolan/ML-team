# %% [markdown]
# # Teoria de la informacion
# ### Autor: Dylan Jara Carvajal; Profesor: Francisco Moreno

# %%
import pandas as pd
import numpy as np

# %%
# 1. Cargar datos
df = pd.read_csv('Egresos_Hospitalarios_2019.csv', encoding='latin-1', on_bad_lines='skip', sep=';')
df
# Out:
# C:\Users\djara\AppData\Local\Temp\ipykernel_24176\2679126958.py:2: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Egresos_Hospitalarios_2019.csv', encoding='latin-1', on_bad_lines='skip', sep=';')
#                                       ID_PACIENTE  ESTABLECIMIENTO_SALUD  \
# 0        49CF1A97C608C2C9E8C00AFEC967DBD0142BED63                 116105
# 1        DB7397E97B41B9528BF9B418E4A5BFE9C95474A6                 116105
# 2        8E201A0C32696A8C62FDF8AE034AFEB3A0A10875                 116105
# 3        23D7D72D63E9FDE0EB6C6FC1F7C73B5EB24AC2BF                 116105
# 4        7DC7A71CDAF0F5E29627BBB767348071112CBE57                 116105
# ...                                           ...                    ...
# 1059731  CF1A9CE035E7CC61358E70350CCF329E36603AEB                 111200
# 1059732  D06F2F51FCAA4CD59B394E7688C993879622BC08                 111200
# 1059733  4A7913BF396A80B016D98BE56CEE98258431F214                 111200
# 1059734  9D8B5661E121AA2C3C5DE7AD23B6221C18006741                 111200
# 1059735  E5C40A65CF1AEFFF6884E35E624ED2BDCCDE7058                 111200
#
#                           GLOSA_ESTABLECIMIENTO_SALUD  \
# 0        Hospital Dr. César Garavagno Burotto (Talca)
# 1        Hospital Dr. César Garavagno Burotto (Talca)
# 2        Hospital Dr. César Garavagno Burotto (Talca)
# 3        Hospital Dr. César Garavagno Burotto (Talca)
# 4        Hospital Dr. César Garavagno Burotto (Talca)
# ...                                               ...
# 1059731        Hospital Clínico Universidad Católica
# 1059732        Hospital Clínico Universidad Católica
# 1059733        Hospital Clínico Universidad Católica
# 1059734        Hospital Clínico Universidad Católica
# 1059735        Hospital Clínico Universidad Católica
#
#                          PERTENENCIA_ESTABLECIMIENTO_SALUD  SEREMI  \
# 0        Pertenecientes al Sistema Nacional de Servicio...     NaN
# 1        Pertenecientes al Sistema Nacional de Servicio...     NaN
# 2        Pertenecientes al Sistema Nacional de Servicio...     NaN
# 3        Pertenecientes al Sistema Nacional de Servicio...     NaN
# 4        Pertenecientes al Sistema Nacional de Servicio...     NaN
# ...                                                    ...     ...
# 1059731  No Pertenecientes al Sistema Nacional de Servi...    13.0
# 1059732  No Pertenecientes al Sistema Nacional de Servi...    13.0
# 1059733  No Pertenecientes al Sistema Nacional de Servi...    13.0
# 1059734  No Pertenecientes al Sistema Nacional de Servi...    13.0
# 1059735  No Pertenecientes al Sistema Nacional de Servi...    13.0
#
#          SERVICIO_DE_SALUD  SEXO FECHA_NACIMIENTO  EDAD_CANT  TIPO_EDAD  ...  \
# 0                     16.0   2.0       1939-09-07         79          1  ...
# 1                     16.0   2.0       1991-03-27         28          1  ...
# 2                     16.0   1.0       1955-04-26         64          1  ...
# 3                     16.0   2.0       1992-02-24         27          1  ...
# 4                     16.0   2.0       1959-03-23         60          1  ...
# ...                    ...   ...              ...        ...        ...  ...
# 1059731                NaN   1.0       1975-02-22         44          1  ...
# 1059732                NaN   1.0       1976-02-20         43          1  ...
# 1059733                NaN   2.0       1978-12-20         40          1  ...
# 1059734                NaN   2.0       2006-04-24         13          1  ...
# 1059735                NaN   2.0       2005-03-29         14          1  ...
#
#          DIAG1                                        GLOSA_DIAG1  DIAG2  \
# 0         I678  OTRAS ENFERMEDADES CEREBROVASCULARES ESPECIFIC...    NaN
# 1         O990  ANEMIA QUE COMPLICA EL EMBARAZO, EL PARTO Y EL...    NaN
# 2         K704                  INSUFICIENCIA HEPATICA ALCOHOLICA    NaN
# 3         E111  DIABETES MELLITUS NO INSULINODEPENDIENTE CON C...    NaN
# 4         D397  TUMOR DE COMPORTAMIENTO INCIERTO O DESCONOCIDO...    NaN
# ...        ...                                                ...    ...
# 1059731   A099  GASTROENTERITIS Y COLITIS DE ORIGEN NO ESPECIF...    NaN
# 1059732   M512  OTROS DESPLAZAMIENTOS DE DISCO INTERVERTEBRAL,...    NaN
# 1059733   N809                     ENDOMETRIOSIS, NO ESPECIFICADA    NaN
# 1059734   D500  ANEMIA POR DEFICIENCIA DE HIERRO SECUNDARIA A ...    NaN
# 1059735   Z090                 EXAMEN DE SEGUIMIENTO CONSECUTIVO     NaN
#
#         GLOSA_DIAG2  INTERV_Q CODIGO_INTERV_Q_PPAL  \
# 0               NaN       2.0                  NaN
# 1               NaN       1.0            2004006.0
# 2               NaN       2.0                  NaN
# 3               NaN       2.0                  NaN
# 4               NaN       1.0            2003031.0
# ...             ...       ...                  ...
# 1059731         NaN       2.0                  NaN
# 1059732         NaN       1.0            1103049.0
# 1059733         NaN       2.0                  NaN
# 1059734         NaN       2.0                  NaN
# 1059735         NaN       NaN                  NaN
#
#                                        GLOSA_INTERV_Q_PPAL PROCED  \
# 0                                                      NaN    2.0
# 1            Cesárea c/s salpingoligadura o salpingectomía    2.0
# 2                                                      NaN    2.0
# 3                                                      NaN    2.0
# 4        Videolaparoscopía ginecológica exploradora (in...    2.0
# ...                                                    ...    ...
# 1059731                                                NaN    2.0
# 1059732  Hernia núcleo pulposo, estenorraquis, aracnoid...    2.0
# 1059733                                                NaN    2.0
# 1059734                                                NaN    2.0
# 1059735                                                NaN    NaN
#
#          CODIGO_PROCED_PPAL GLOSA_PROCED_PPAL
# 0                       NaN               NaN
# 1                       NaN               NaN
# 2                       NaN               NaN
# 3                       NaN               NaN
# 4                       NaN               NaN
# ...                     ...               ...
# 1059731                 NaN               NaN
# 1059732                 NaN               NaN
# 1059733                 NaN               NaN
# 1059734                 NaN               NaN
# 1059735                 NaN               NaN
#
# [1059736 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['ID_PACIENTE', 'ESTABLECIMIENTO_SALUD', 'GLOSA_ESTABLECIMIENTO_SALUD',
#        'PERTENENCIA_ESTABLECIMIENTO_SALUD', 'SEREMI', 'SERVICIO_DE_SALUD',
#        'SEXO', 'FECHA_NACIMIENTO', 'EDAD_CANT', 'TIPO_EDAD', 'EDAD_A_OS',
#        'PUEBLO_ORIGINARIO', 'PAIS_ORIGEN', 'GLOSA_PAIS_ORIGEN',
#        'COMUNA_RESIDENCIA', 'GLOSA_COMUNA_RESIDENCIA', 'REGION_RESIDENCIA',
#        'GLOSA_REGION_RESIDENCIA', 'PREVISION', 'BENEFICIARIO', 'MODALIDAD',
#        'PROCEDENCIA', 'ANO_EGRESO', 'FECHA_EGRESO', 'AREA_FUNCIONAL_EGRESO',
#        'DIAS_ESTADA', 'CONDICION_EGRESO', 'DIAG1', 'GLOSA_DIAG1', 'DIAG2',
#        'GLOSA_DIAG2', 'INTERV_Q', 'CODIGO_INTERV_Q_PPAL',
#        'GLOSA_INTERV_Q_PPAL', 'PROCED', 'CODIGO_PROCED_PPAL',
#        'GLOSA_PROCED_PPAL'],
#       dtype='object')

# %%
counts_2019 = df['GLOSA_REGION_RESIDENCIA'].value_counts().sort_index()
counts_2019
# Out:
# GLOSA_REGION_RESIDENCIA
# De Aisén del Gral. C. Ibáñez del Campo      12019
# De Antofagasta                              54402
# De Arica y Parinacota                       18856
# De Atacama                                  22781
# De Coquimbo                                 50887
# De La Araucanía                             96058
# De Los Lagos                                80215
# De Los Ríos                                 42317
# De Magallanes y de La Antártica Chilena     20921
# De Tarapacá                                 25820
# De Valparaíso                              157173
# De Ñuble                                    42085
# Del Bíobío                                 162407
# Del Libertador B. O'Higgins                  2655
# Del Maule                                   42426
# Extranjero                                   3394
# Ignorada                                     3036
# Metropolitana de Santiago                  222281
# Name: count, dtype: int64

# %% [markdown]
# # Aqui existen las 16 regiones, ademas de Extranjero e Ignorada

# %%
print(f'La cantidad de regiones es: {len(counts_2019)}. Ademas la cantidad de registros es: {counts_2019.sum()}')
# Out:
# La cantidad de regiones es: 18. Ademas la cantidad de registros es: 1059733

# %% [markdown]
# # Obtenemos la frecuencia absoluta

# %%
X = counts_2019.values / counts_2019.sum()

# %%
# Usamos la distribución uniforme para la parte b de KL
num_regiones = len(X)
Y = np.full(num_regiones, 1/num_regiones)

# %% [markdown]
# # Divergencia de Kullback-Leibler

# %%
def kl_divergence(p, q):
    #Añadimos un valor epsilon infinitesimal para evitar log(0) o divisiones por 0
    epsilon = 1e-10
    p = p + epsilon
    q = q + epsilon
    return np.sum(p * np.log(p / q))

# %%
# 4. Resultado
resultado_kl = kl_divergence(X, Y)
print(f"Divergencia KL entre 2019 y Uniforme: {resultado_kl}")
# Out:
# Divergencia KL entre 2019 y Uniforme: 0.4723081447032801

# %% [markdown]
# # Divergencia de Renyi

# %%
def renyi_divergence(p, q, alpha):
    #Pasamos las distribuciones como arrays de numpy
    p = np.asarray(p, dtype=float)
    q = np.asarray(q, dtype=float)
    
    #Epsilon para evitar ceros
    epsilon = 1e-10
    p = np.clip(p, epsilon, 1) #p array, epsilon minimo, 1 maximo. Los valores fuera del intervalo se convierten en las cotas
    q = np.clip(q, epsilon, 1)
    
    if alpha == 1:
        # alpha = 1 equivale a KL
        return np.sum(p * np.log(p / q))
    else:
        sum_term = np.sum((p**alpha) * (q**(1-alpha)))
        return (1.0 / (alpha - 1.0)) * np.log(sum_term)

# %%
alphas = [0.1, 0.5, 2, 5]
resultados = []

for a in alphas:
    d_renyi = renyi_divergence(X, Y, a)
    resultados.append({'Alpha': a, 'Renyi': d_renyi})

df_renyi = pd.DataFrame(resultados)
print("Divergencia de Rényi para X vs Uniforme (Y):")
print(df_renyi)
# Out:
# Divergencia de Rényi para X vs Uniforme (Y):
#    Alpha     Renyi
# 0    0.1  0.062218
# 1    0.5  0.274275
# 2    2.0  0.728036
# 3    5.0  1.023709
