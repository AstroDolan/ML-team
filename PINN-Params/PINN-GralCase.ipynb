# %%
import numpy as np # type: ignore
import pandas as pd # type: ignore
import scipy as sp # type: ignore
from scipy.optimize import curve_fit # type: ignore
import matplotlib.pyplot as plt # type: ignore

#Functional API
import tensorflow as tf # type: ignore
from tensorflow import keras # type: ignore
from keras.models import Model # type: ignore
import keras.optimizers # type: ignore
from keras.layers import Dense, Input # type: ignore

# UNITS
ev2au = 1/27.211396132
au2ev = 27.211396132
ang2au = 1/0.529177249
au2ang = 0.529177249
au2fs = 1/41.34137333656
fs2au = 41.34137333656
au2debye = 1/0.39343
debye2au = 0.39343
au2nm = 0.052917720859
nm2au = 1/0.052917720859
au2cm1 = 2.1947463137E5
cm12au = 1/(2.1947463137E5)
au2amu = 1/1822.88848325
amu2au = 1822.88848325
thz2au = 1.0/0.029979/au2cm1
# Out:
# 2025-05-17 17:29:23.161055: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-17 17:29:23.414395: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-17 17:29:23.649198: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747517363.887055   12305 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747517363.950200   12305 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
#La suma debe ser una suma de 32 terminos

coeff_matrix = np.zeros((32,4))
coeff_matrix[0,:] = [0,0,1,32849.58]
coeff_matrix[1,:] = [0,1,1,-17553.99]
coeff_matrix[2,:] = [1,0,1,-27625.23]
coeff_matrix[3,:] = [2,0,0,50043.09]
coeff_matrix[4,:] = [4,0,0,336.49]
coeff_matrix[5,:] = [0,1,2,-3360.94]
coeff_matrix[6,:] = [0,3,0,-64.84]
coeff_matrix[7,:] = [1,1,1,18285.40]
coeff_matrix[8,:] = [2,0,1,-7181.44]
coeff_matrix[9,:] = [0,0,4,2553.25]
coeff_matrix[10,:] = [0,2,2,-4905.39]
coeff_matrix[11,:] = [0,4,0,3505.21]
coeff_matrix[12,:] = [1,1,2,-21845.86]
coeff_matrix[13,:] = [1,3,0,-1416.44]
coeff_matrix[14,:] = [2,1,1,5596.86]
coeff_matrix[15,:] = [3,0,1,-142.39]
coeff_matrix[16,:] = [0,0,2,15623.64]
coeff_matrix[17,:] = [0,2,0,72972.84]
coeff_matrix[18,:] = [1,1,0,9857.17]
coeff_matrix[19,:] = [3,0,0,-2376.30]
coeff_matrix[20,:] = [0,2,1,-8550.95]
coeff_matrix[21,:] = [1,0,2,-4597.25]
coeff_matrix[22,:] = [1,2,0,-657.28]
coeff_matrix[23,:] = [2,1,0,1985.36]
coeff_matrix[24,:] = [0,1,3,-5546.12]
coeff_matrix[25,:] = [0,3,1,-11098.50]
coeff_matrix[26,:] = [1,0,3,-9178.03]
coeff_matrix[27,:] = [1,2,1,948.74]
coeff_matrix[28,:] = [2,0,2,-983.04]
coeff_matrix[29,:] = [2,2,0,-584.78]
coeff_matrix[30,:] = [3,1,0,1694.77]
coeff_matrix[31,:] = [0,0,3,4971.79]

def V(R1,R2,theta):
    R1e = 1.5614*ang2au #Amstrong C-S bond; R1e: Equilibrium value of R1
    R2e = 1.1562*ang2au #Amstrong C-O bond; R2e: Equilibrium value of R2
    alpha_1 = 1.95/ang2au #Amstrong^-1
    alpha_2 = 2.34/ang2au #Amstrong^-1
    theta_e = np.pi #Degrees

    aR1 = -alpha_1*(R1-R1e)
    aR2 = -alpha_2*(R2-R2e)

    y_1 = 1.0 - np.exp(aR1)
    y_2 = 1.0 - np.exp(aR2)
    y_3 = np.cos(theta) - np.cos(theta_e)

    suma = 0.0
    for i in range(32):
        suma = suma + (coeff_matrix[i,3]*cm12au)*(y_1**int(coeff_matrix[i,0]))*(y_2**int(coeff_matrix[i,1]))*(y_3**(coeff_matrix[i,2]))
    return(suma)

# %%
q1 = np.concatenate((np.linspace(1.45,5.0,20),np.linspace(5.0, 8, 7))) #Azul
q2 = np.concatenate((np.linspace(1.6,5.0,20),np.linspace(5.0, 8, 7))) #Naranja
R1_eq = 1.5614*ang2au #Amstrong C-S bond; R1e: Equilibrium value of R1
R2_eq = 1.1562*ang2au #Amstrong C-O bond; R2e: Equilibrium value of R2
theta_eq = np.pi
plt.plot(q1, V(R1_eq,q1,theta_eq), "o-")
plt.plot(q2, V(q2,R2_eq,theta_eq), "o-")
plt.axis([1.1,10,-0.05,5])
plt.title("Potenciales de energia de superficie")
# Out:
# Text(0.5, 1.0, 'Potenciales de energia de superficie')

# %%
print(V(R1_eq,7.5,np.pi))
print(V(7.5,R2_eq,np.pi))
# Out:
# 0.3471562712767736
# 0.21480652798375546

# %%
R1e_values = np.linspace(2.1, 5, 29)
R2e_values = np.linspace(1.8, 4, 29) 

R1e, R2e = np.meshgrid(R1e_values, R2e_values)
energia_superficie = np.vectorize(V)(R1e, R2e, np.pi) #np.vectorize para aplicar la función a matrices

plt.contourf(R1e, R2e, energia_superficie,300)
plt.colorbar(label='Energía de Superficie')

plt.xlabel('R1e (angstrom)')
plt.ylabel('R2e (angstrom)')
plt.title('Gráfico de Contorno de Energía de Superficie')
# Out:
# Text(0.5, 1.0, 'Gráfico de Contorno de Energía de Superficie')

# %%
# Generacion del archivo de datos
data_set = np.zeros((len(q1)**2,3)) #Dim(729,3)
l = 0 #Inicializa en 0
for i in range(len(q1)): #R1
    for j in range(len(q2)): #R2
        data_set[l,:] = q1[i],q2[j],V(q1[i],q2[j],np.pi) #Obtenemos valores para R1, R2 y V(R1,R2)
        l = l + 1

df = pd.DataFrame(data_set)
df.to_csv('PotencialOCS_2.csv')
df.columns = ['R1','R2','V'] #Renombramos las columnas

# %%
inputsmodel = df.drop('V', axis=1)
target = df.iloc[:,-1]

# %%
#Creamos una funcion custom_loss incluyendo la perdida fisica de la pinn.
from scipy.optimize import curve_fit # type: ignore

def morsepotential(q, D, alpha, E0, R_eq):
    return D*(1.0 - np.exp(-alpha*(q-R_eq)))**2 + E0

xdata = np.concatenate((np.linspace(1.6,5.0,30),np.linspace(5.0, 8, 7))) #q2
morse_parameters = np.zeros((len(q1),5))

for i in range(len(q1)): #En este range cambio la forma de graficar
    ydata = V(q1[i],xdata,theta_eq) #Potencial segun xdata
    popt, pcov = curve_fit(morsepotential, xdata, ydata, p0=[3.49440974e-01,  1.22952512e+00, -1.73828756e-03    ,  2.18903764e+00]) #Se hace el fitting considerando un p0 inicial para el resto
    
    morse_parameters[i,0] = q1[i]
    morse_parameters[i,1:] = popt
    
    #plt.title("Fitting de curvas morse en parametros de q2")
    #plt.plot(xdata, morsepotential(xdata, *popt), 'r-',label='fit: a=%5.3f, b=%5.3f, c=%5.3f, d=%5.3f' % 
    #tuple(popt)) #Ploteo todos los popt calculados segun el ciclo for
    
    dfMorse = pd.DataFrame(morse_parameters[:]) #Creo el dataset de los valores
    dfMorse.columns = ['q','D','alpha','E','Req']

dfaxu = pd.DataFrame(dfMorse.loc[dfMorse.index.repeat(27)].reset_index(drop=True))
dfFinal = pd.concat([df,dfaxu],axis=1)

# %%
fit_v = []

for i, row, in dfFinal.iterrows():
    R2 = row['R2']
    D = row['D']
    alpha = row['alpha']
    E = row['E']
    Req = row['Req']
    
    potential = morsepotential(R2,D,alpha,E,Req)
    fit_v.append(potential)
    
dfFinal['VFitting'] = fit_v

# %% [markdown]
# ## Loss: Fitting Potential Values + $\lambda = 0.01$
# En pinnLoss se cambia (y_pred - lossRi) por (y_pred - lossV) para variar entre morse y potencial de fitting

# %%
def custom_loss(target, y_pred):
    lossV = dfFinal['VFitting']

    pinnLoss = tf.math.reduce_mean(tf.square(y_pred - lossV))
    pinnLoss_tf = tf.convert_to_tensor(pinnLoss, dtype=tf.float32)

    mse_loss = tf.math.reduce_mean(tf.square(y_pred - target))
    mse_loss_tf = tf.convert_to_tensor(mse_loss, dtype=tf.float32)
    numlambda = 0.1
    totalloss = mse_loss_tf + numlambda*pinnLoss_tf
    return totalloss

# %% [markdown]
# # Creacion de modelos replicados para comparacion de resultados $(m=5)$

# %%
tf.random.set_seed(5)
np.random.seed(5)
eplist = [100, 200, 250]
pv = 0.20

loss_histories = {}
y_preds = {}
models = []
histories = []



for epochs in eplist:
    print(f"Entrenando modelo con {epochs} épocas")
    inputs1 = Input(shape=(2,))
    hidden11 = Dense(75, activation='relu')(inputs1)
    hidden12 = Dense(100, activation='relu')(hidden11)
    hidden13 = Dense(100, activation='relu')(hidden12)
    hidden14 = Dense(100, activation='relu')(hidden13)
    hidden15 = Dense(100, activation='relu')(hidden14)
    hidden16 = Dense(100, activation='relu')(hidden15)
    hidden17 = Dense(90, activation='relu')(hidden16)
    output1 = Dense(1, activation='linear')(hidden17)
    model1 = Model(inputs=inputs1, outputs=output1)

    opt1 = keras.optimizers.RMSprop(learning_rate=0.01)
    model1.compile(optimizer=opt1, loss=custom_loss, metrics=['mae'])

    history = model1.fit(inputsmodel, target, epochs=epochs, validation_split=pv, batch_size=480)
    loss_histories[epochs] = history.history
    y_preds[epochs] = model1.predict(inputsmodel)

    v_true = df['V'].to_numpy().reshape(-1)
    v_pred = y_preds[epochs].reshape(-1)

    np.save(f'TrainFOR_'+'ep:'+str(epochs)+'.npy', np.array([history.history['val_loss'],history.history['loss']]))
    np.save(f'ResultsFOR_ep{epochs}.npy', np.stack([v_true, v_pred], axis=1))

    #models.append(model1)
    #histories.append(history)


#history = model.fit(inputsmodel, target, epochs=ep, validation_split=pv, batch_size=480)
#loss_histories[lr] = history.history
#y_preds[lr] = model.predict(inputsmodel)

# Optimizer.
# Learning-Rate.
# Activation functions.
# Number of layers.
# Find a pattern for the number of neurons per layer.


# Como mejora la regression o la predicción con PINN.
# Out:
# Entrenando modelo con 100 épocas
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 446ms/step - loss: 26.1831 - mae: 2.2551 - val_loss: 0.3669 - val_mae: 0.4975
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 1.2668 - mae: 0.6742 - val_loss: 3.5070 - val_mae: 1.7534
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 2.5999 - mae: 1.3910 - val_loss: 0.1701 - val_mae: 0.2765
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 1.0385 - mae: 0.4952 - val_loss: 0.2335 - val_mae: 0.3972
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.8163 - mae: 0.5796 - val_loss: 0.1978 - val_mae: 0.3505
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.7949 - mae: 0.5818 - val_loss: 0.1265 - val_mae: 0.2306
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.7535 - mae: 0.5485 - val_loss: 0.1320 - val_mae: 0.2374
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.7829 - mae: 0.6049 - val_loss: 0.0817 - val_mae: 0.0958
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.6925 - mae: 0.4991 - val_loss: 0.0812 - val_mae: 0.0949
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.7050 - mae: 0.5137 - val_loss: 0.0823 - val_mae: 0.0939
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.6502 - mae: 0.4763 - val_loss: 0.0818 - val_mae: 0.1025
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.6956 - mae: 0.5051 - val_loss: 0.0901 - val_mae: 0.1148
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.6309 - mae: 0.4620 - val_loss: 0.0882 - val_mae: 0.1380
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5918 - mae: 0.4197 - val_loss: 0.1427 - val_mae: 0.2443
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 1.4389 - mae: 0.9103 - val_loss: 0.0876 - val_mae: 0.1126
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.8663 - mae: 0.4403 - val_loss: 0.0996 - val_mae: 0.1583
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.7746 - mae: 0.4783 - val_loss: 0.1679 - val_mae: 0.3047
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.8499 - mae: 0.6692 - val_loss: 0.1008 - val_mae: 0.1467
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.7286 - mae: 0.4957 - val_loss: 0.0798 - val_mae: 0.1076
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.7003 - mae: 0.5298 - val_loss: 0.0987 - val_mae: 0.1450
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.6079 - mae: 0.4485 - val_loss: 0.0814 - val_mae: 0.1166
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.6283 - mae: 0.4538 - val_loss: 0.0803 - val_mae: 0.1041
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.5779 - mae: 0.4361 - val_loss: 0.0819 - val_mae: 0.1189
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.8963 - mae: 0.6344 - val_loss: 0.6072 - val_mae: 0.7057
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.9643 - mae: 0.6232 - val_loss: 0.0898 - val_mae: 0.1156
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.7259 - mae: 0.4704 - val_loss: 0.0816 - val_mae: 0.1174
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.5711 - mae: 0.4094 - val_loss: 0.4722 - val_mae: 0.5800
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 1.2784 - mae: 0.7064 - val_loss: 0.0781 - val_mae: 0.0974
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.8868 - mae: 0.4429 - val_loss: 0.0784 - val_mae: 0.1045
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.8631 - mae: 0.4325 - val_loss: 0.0839 - val_mae: 0.0931
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.8128 - mae: 0.4568 - val_loss: 0.0858 - val_mae: 0.1045
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.7777 - mae: 0.4699 - val_loss: 0.1079 - val_mae: 0.1752
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.9019 - mae: 0.4339 - val_loss: 0.0829 - val_mae: 0.1195
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.7684 - mae: 0.4507 - val_loss: 0.4112 - val_mae: 0.5268
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.8890 - mae: 0.5478 - val_loss: 0.0817 - val_mae: 0.1109
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.7190 - mae: 0.4569 - val_loss: 0.0802 - val_mae: 0.1105
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.6947 - mae: 0.5510 - val_loss: 0.0969 - val_mae: 0.1358
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.5839 - mae: 0.4720 - val_loss: 0.0848 - val_mae: 0.1280
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.7961 - mae: 0.5305 - val_loss: 0.0928 - val_mae: 0.1205
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.7398 - mae: 0.4352 - val_loss: 0.0807 - val_mae: 0.1083
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.5912 - mae: 0.4357 - val_loss: 0.0817 - val_mae: 0.1157
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.7703 - mae: 0.5966 - val_loss: 0.1258 - val_mae: 0.2122
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5616 - mae: 0.4202 - val_loss: 0.0955 - val_mae: 0.1537
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4058 - mae: 0.3324 - val_loss: 0.0844 - val_mae: 0.1276
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - loss: 1.5462 - mae: 0.8461 - val_loss: 2.9141 - val_mae: 1.6091
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.3996 - mae: 0.9396 - val_loss: 0.0806 - val_mae: 0.1124
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.8220 - mae: 0.4270 - val_loss: 0.0850 - val_mae: 0.1290
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.7229 - mae: 0.4243 - val_loss: 0.1080 - val_mae: 0.1762
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.6572 - mae: 0.4005 - val_loss: 0.1475 - val_mae: 0.2374
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.6415 - mae: 0.3845 - val_loss: 0.1060 - val_mae: 0.1725
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.4685 - mae: 0.3318 - val_loss: 0.1276 - val_mae: 0.2076
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.4872 - mae: 0.3377 - val_loss: 0.1449 - val_mae: 0.2338
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.7103 - mae: 0.3924 - val_loss: 0.0840 - val_mae: 0.1265
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.4453 - mae: 0.3799 - val_loss: 0.0816 - val_mae: 0.1173
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.9383 - mae: 0.6561 - val_loss: 0.0913 - val_mae: 0.1182
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.5900 - mae: 0.3658 - val_loss: 0.0869 - val_mae: 0.1345
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.4483 - mae: 0.3563 - val_loss: 0.0876 - val_mae: 0.1365
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.4683 - mae: 0.3807 - val_loss: 0.0814 - val_mae: 0.1108
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.9012 - mae: 0.6490 - val_loss: 0.0832 - val_mae: 0.1218
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4046 - mae: 0.3131 - val_loss: 0.0826 - val_mae: 0.1177
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.4030 - mae: 0.3114 - val_loss: 0.0836 - val_mae: 0.1146
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.5656 - mae: 0.4757 - val_loss: 0.0935 - val_mae: 0.1499
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.4658 - mae: 0.3918 - val_loss: 0.0891 - val_mae: 0.1177
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.4229 - mae: 0.3700 - val_loss: 0.0866 - val_mae: 0.1337
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.6207 - mae: 0.4528 - val_loss: 0.0990 - val_mae: 0.1402
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.4278 - mae: 0.3348 - val_loss: 0.0850 - val_mae: 0.1143
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3356 - mae: 0.2902 - val_loss: 0.0881 - val_mae: 0.1189
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.7709 - mae: 0.5053 - val_loss: 0.0849 - val_mae: 0.1079
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.6127 - mae: 0.3618 - val_loss: 0.0970 - val_mae: 0.1567
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.4172 - mae: 0.3624 - val_loss: 0.1058 - val_mae: 0.1545
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.7856 - mae: 0.5874 - val_loss: 0.1331 - val_mae: 0.2164
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.3936 - mae: 0.3374 - val_loss: 0.0829 - val_mae: 0.1190
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2975 - mae: 0.2709 - val_loss: 0.0848 - val_mae: 0.1126
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.5363 - mae: 0.3674 - val_loss: 0.1727 - val_mae: 0.2938
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5474 - mae: 0.3931 - val_loss: 0.0933 - val_mae: 0.1494
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.2499 - mae: 0.2420 - val_loss: 0.0829 - val_mae: 0.1150
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.4649 - mae: 0.3438 - val_loss: 0.1948 - val_mae: 0.3275
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.5932 - mae: 0.4101 - val_loss: 0.1068 - val_mae: 0.1740
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.3642 - mae: 0.3299 - val_loss: 0.0902 - val_mae: 0.1151
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.4002 - mae: 0.3940 - val_loss: 0.0846 - val_mae: 0.1275
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.6848 - mae: 0.5143 - val_loss: 0.0847 - val_mae: 0.1127
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.3644 - mae: 0.2949 - val_loss: 0.0847 - val_mae: 0.1135
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.2568 - mae: 0.2545 - val_loss: 0.0836 - val_mae: 0.1203
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.7518 - mae: 0.4608 - val_loss: 0.1385 - val_mae: 0.2344
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.6130 - mae: 0.3791 - val_loss: 0.0889 - val_mae: 0.1397
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.3865 - mae: 0.3618 - val_loss: 0.0830 - val_mae: 0.1153
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4723 - mae: 0.4008 - val_loss: 0.0832 - val_mae: 0.1168
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4478 - mae: 0.3807 - val_loss: 0.0905 - val_mae: 0.1206
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.2553 - mae: 0.2352 - val_loss: 0.1013 - val_mae: 0.1466
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.4201 - mae: 0.3129 - val_loss: 0.0977 - val_mae: 0.1379
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.2760 - mae: 0.2831 - val_loss: 0.0844 - val_mae: 0.1264
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.4567 - mae: 0.3509 - val_loss: 0.0822 - val_mae: 0.1135
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.2374 - mae: 0.2413 - val_loss: 0.0839 - val_mae: 0.1093
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.2137 - mae: 0.2001 - val_loss: 0.0839 - val_mae: 0.1115
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 1.4396 - mae: 0.6923 - val_loss: 0.1631 - val_mae: 0.2604
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.5013 - mae: 0.3380 - val_loss: 0.0847 - val_mae: 0.1113
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.2556 - mae: 0.2423 - val_loss: 0.0825 - val_mae: 0.1135
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.2259 - mae: 0.2192 - val_loss: 0.0835 - val_mae: 0.1108
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.3051 - mae: 0.2731 - val_loss: 0.0844 - val_mae: 0.1130
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.7534 - mae: 0.5076 - val_loss: 0.0889 - val_mae: 0.1393
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Entrenando modelo con 200 épocas
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 434ms/step - loss: 226.1669 - mae: 5.2968 - val_loss: 0.3302 - val_mae: 0.4625
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.3842 - mae: 0.7540 - val_loss: 0.3450 - val_mae: 0.4767
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 1.2707 - mae: 0.6550 - val_loss: 0.6320 - val_mae: 0.7231
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.9499 - mae: 0.6857 - val_loss: 0.0799 - val_mae: 0.1015
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.8137 - mae: 0.4610 - val_loss: 0.0779 - val_mae: 0.0918
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.7797 - mae: 0.4435 - val_loss: 0.1415 - val_mae: 0.2288
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.7955 - mae: 0.4216 - val_loss: 0.1776 - val_mae: 0.2891
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.8016 - mae: 0.4165 - val_loss: 0.1244 - val_mae: 0.1935
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.6875 - mae: 0.4215 - val_loss: 0.1666 - val_mae: 0.2718
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.7192 - mae: 0.4071 - val_loss: 0.2099 - val_mae: 0.3317
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.8082 - mae: 0.4174 - val_loss: 0.0825 - val_mae: 0.1153
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.6719 - mae: 0.4929 - val_loss: 0.0796 - val_mae: 0.1088
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.6247 - mae: 0.4662 - val_loss: 0.0801 - val_mae: 0.1103
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.7419 - mae: 0.5402 - val_loss: 0.0922 - val_mae: 0.1465
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.6530 - mae: 0.3947 - val_loss: 0.0834 - val_mae: 0.1228
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.5864 - mae: 0.4477 - val_loss: 0.0815 - val_mae: 0.1166
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.6946 - mae: 0.5238 - val_loss: 0.0846 - val_mae: 0.1283
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.5573 - mae: 0.3926 - val_loss: 0.0899 - val_mae: 0.1404
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.5631 - mae: 0.4342 - val_loss: 0.0796 - val_mae: 0.1096
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.6028 - mae: 0.4741 - val_loss: 0.0823 - val_mae: 0.1206
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5027 - mae: 0.4086 - val_loss: 0.0846 - val_mae: 0.1266
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.7513 - mae: 0.5247 - val_loss: 0.0861 - val_mae: 0.0983
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.7513 - mae: 0.4281 - val_loss: 0.0805 - val_mae: 0.1112
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5525 - mae: 0.4385 - val_loss: 0.0817 - val_mae: 0.0977
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.8158 - mae: 0.6438 - val_loss: 0.0823 - val_mae: 0.1206
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.6149 - mae: 0.3802 - val_loss: 0.0844 - val_mae: 0.1271
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.5114 - mae: 0.4358 - val_loss: 0.0818 - val_mae: 0.1174
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.7392 - mae: 0.5591 - val_loss: 0.0788 - val_mae: 0.0970
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5898 - mae: 0.3896 - val_loss: 0.0901 - val_mae: 0.1419
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.4726 - mae: 0.4021 - val_loss: 0.0798 - val_mae: 0.1069
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 1.1921 - mae: 0.7312 - val_loss: 0.0832 - val_mae: 0.0978
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.8480 - mae: 0.4454 - val_loss: 0.0809 - val_mae: 0.0937
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.7704 - mae: 0.4667 - val_loss: 0.0927 - val_mae: 0.1475
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.6738 - mae: 0.4350 - val_loss: 0.2323 - val_mae: 0.3571
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 1.0084 - mae: 0.5199 - val_loss: 0.0880 - val_mae: 0.1097
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.6746 - mae: 0.5182 - val_loss: 0.0797 - val_mae: 0.1093
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.7308 - mae: 0.5571 - val_loss: 0.0894 - val_mae: 0.1150
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.6116 - mae: 0.4310 - val_loss: 0.0816 - val_mae: 0.1177
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.5097 - mae: 0.3968 - val_loss: 0.0909 - val_mae: 0.1229
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1.8135 - mae: 1.0737 - val_loss: 0.1524 - val_mae: 0.2669
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.8942 - mae: 0.4713 - val_loss: 0.1323 - val_mae: 0.2342
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.8258 - mae: 0.4957 - val_loss: 0.1559 - val_mae: 0.2804
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.8080 - mae: 0.5434 - val_loss: 0.0864 - val_mae: 0.1025
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.7319 - mae: 0.4738 - val_loss: 0.1042 - val_mae: 0.1721
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.7319 - mae: 0.5605 - val_loss: 0.1024 - val_mae: 0.1509
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5620 - mae: 0.4360 - val_loss: 0.0843 - val_mae: 0.1274
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5528 - mae: 0.4262 - val_loss: 0.0819 - val_mae: 0.1028
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.8781 - mae: 0.6582 - val_loss: 0.0817 - val_mae: 0.1041
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.4927 - mae: 0.3621 - val_loss: 0.0944 - val_mae: 0.1512
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.6228 - mae: 0.3607 - val_loss: 0.0944 - val_mae: 0.1513
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.3698 - mae: 0.3028 - val_loss: 0.0846 - val_mae: 0.1276
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.7855 - mae: 0.4113 - val_loss: 0.0976 - val_mae: 0.1564
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 1.6115 - mae: 0.8265 - val_loss: 2.0929 - val_mae: 1.3608
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 1.2305 - mae: 0.8548 - val_loss: 0.1075 - val_mae: 0.1811
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - loss: 0.7818 - mae: 0.4756 - val_loss: 0.3043 - val_mae: 0.4728
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.8677 - mae: 0.6607 - val_loss: 0.0859 - val_mae: 0.1004
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.7637 - mae: 0.4462 - val_loss: 0.0791 - val_mae: 0.1075
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.7158 - mae: 0.4240 - val_loss: 0.0919 - val_mae: 0.1455
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.9105 - mae: 0.4323 - val_loss: 0.0798 - val_mae: 0.0983
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.8151 - mae: 0.4319 - val_loss: 0.1625 - val_mae: 0.2602
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.6809 - mae: 0.3915 - val_loss: 0.1438 - val_mae: 0.2324
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5272 - mae: 0.3668 - val_loss: 0.1516 - val_mae: 0.2436
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.7287 - mae: 0.4376 - val_loss: 0.0836 - val_mae: 0.1005
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.8361 - mae: 0.4279 - val_loss: 0.1401 - val_mae: 0.2266
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.7080 - mae: 0.3934 - val_loss: 0.2301 - val_mae: 0.3533
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.6130 - mae: 0.3736 - val_loss: 0.1094 - val_mae: 0.1775
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4621 - mae: 0.3540 - val_loss: 0.0815 - val_mae: 0.1170
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.8051 - mae: 0.5735 - val_loss: 5.1549 - val_mae: 2.1496
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.8418 - mae: 1.1599 - val_loss: 0.1102 - val_mae: 0.1793
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.6175 - mae: 0.4862 - val_loss: 0.1021 - val_mae: 0.1542
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.7465 - mae: 0.4566 - val_loss: 0.0886 - val_mae: 0.1381
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.5386 - mae: 0.4171 - val_loss: 0.0879 - val_mae: 0.1373
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4223 - mae: 0.3323 - val_loss: 0.0961 - val_mae: 0.1330
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.6152 - mae: 0.4590 - val_loss: 0.0885 - val_mae: 0.1131
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.9119 - mae: 0.4489 - val_loss: 0.2055 - val_mae: 0.3219
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.9655 - mae: 0.4835 - val_loss: 0.1000 - val_mae: 0.1488
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.8484 - mae: 0.4591 - val_loss: 0.1114 - val_mae: 0.1853
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.7986 - mae: 0.4891 - val_loss: 0.2038 - val_mae: 0.3508
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.7838 - mae: 0.5923 - val_loss: 0.0889 - val_mae: 0.1396
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.6545 - mae: 0.4226 - val_loss: 0.6569 - val_mae: 0.7042
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 1.0403 - mae: 0.6040 - val_loss: 0.0813 - val_mae: 0.1136
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.6184 - mae: 0.4190 - val_loss: 0.1502 - val_mae: 0.2412
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.4416 - mae: 0.3284 - val_loss: 0.5869 - val_mae: 0.6599
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1.0634 - mae: 0.6002 - val_loss: 0.0862 - val_mae: 0.1323
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.6696 - mae: 0.4171 - val_loss: 0.1255 - val_mae: 0.2035
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3834 - mae: 0.3136 - val_loss: 0.3790 - val_mae: 0.5036
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.8984 - mae: 0.4906 - val_loss: 0.0807 - val_mae: 0.1088
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.4694 - mae: 0.4428 - val_loss: 0.0916 - val_mae: 0.1441
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.4717 - mae: 0.7917 - val_loss: 2.0163 - val_mae: 1.3317
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 1.1895 - mae: 0.8330 - val_loss: 0.0806 - val_mae: 0.1119
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.6787 - mae: 0.4256 - val_loss: 0.0894 - val_mae: 0.1400
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.6224 - mae: 0.4091 - val_loss: 0.0897 - val_mae: 0.1247
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.8280 - mae: 0.6709 - val_loss: 0.0813 - val_mae: 0.1015
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.5079 - mae: 0.4180 - val_loss: 0.0921 - val_mae: 0.1464
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.4553 - mae: 0.3720 - val_loss: 0.0804 - val_mae: 0.1083
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.6917 - mae: 0.5652 - val_loss: 0.0815 - val_mae: 0.1112
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.4203 - mae: 0.3669 - val_loss: 0.0874 - val_mae: 0.1359
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.4048 - mae: 0.3442 - val_loss: 0.0824 - val_mae: 0.1201
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.8216 - mae: 0.6081 - val_loss: 0.1040 - val_mae: 0.1516
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4462 - mae: 0.3529 - val_loss: 0.0854 - val_mae: 0.1308
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.3118 - mae: 0.2839 - val_loss: 0.0847 - val_mae: 0.1280
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 2.4803 - mae: 1.1136 - val_loss: 0.3724 - val_mae: 0.5154
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.5808 - mae: 0.4461 - val_loss: 0.0896 - val_mae: 0.1416
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.3990 - mae: 0.3043 - val_loss: 0.0875 - val_mae: 0.1362
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.5146 - mae: 0.4197 - val_loss: 0.0857 - val_mae: 0.1309
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.4004 - mae: 0.3322 - val_loss: 0.0850 - val_mae: 0.1286
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.4049 - mae: 0.3349 - val_loss: 0.0875 - val_mae: 0.1362
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.7188 - mae: 0.5204 - val_loss: 0.0840 - val_mae: 0.1225
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3514 - mae: 0.2952 - val_loss: 0.0835 - val_mae: 0.1177
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.2784 - mae: 0.2400 - val_loss: 0.0840 - val_mae: 0.1230
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.5601 - mae: 0.3990 - val_loss: 0.0930 - val_mae: 0.1254
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.2798 - mae: 0.2657 - val_loss: 0.0838 - val_mae: 0.1211
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3367 - mae: 0.2864 - val_loss: 0.0843 - val_mae: 0.1190
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.9134 - mae: 0.6213 - val_loss: 0.0985 - val_mae: 0.1601
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3282 - mae: 0.2842 - val_loss: 0.0832 - val_mae: 0.1183
# Epoch 116/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.2461 - mae: 0.2304 - val_loss: 0.0920 - val_mae: 0.1236
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.4476 - mae: 0.3503 - val_loss: 0.1074 - val_mae: 0.1587
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.3200 - mae: 0.3237 - val_loss: 0.0951 - val_mae: 0.1535
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.0907 - mae: 0.6403 - val_loss: 0.1203 - val_mae: 0.1865
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.3456 - mae: 0.2983 - val_loss: 0.0847 - val_mae: 0.1186
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2601 - mae: 0.2228 - val_loss: 0.0906 - val_mae: 0.1210
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2593 - mae: 0.2412 - val_loss: 0.0909 - val_mae: 0.1234
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.9470 - mae: 0.5644 - val_loss: 0.0845 - val_mae: 0.1192
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.3310 - mae: 0.2899 - val_loss: 0.0887 - val_mae: 0.1183
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.2443 - mae: 0.2131 - val_loss: 0.1041 - val_mae: 0.1512
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.2878 - mae: 0.2619 - val_loss: 0.0877 - val_mae: 0.1195
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.8182 - mae: 0.5301 - val_loss: 0.1212 - val_mae: 0.1973
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.3772 - mae: 0.3178 - val_loss: 0.0852 - val_mae: 0.1167
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.2365 - mae: 0.2007 - val_loss: 0.1160 - val_mae: 0.1779
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.2680 - mae: 0.2500 - val_loss: 0.1033 - val_mae: 0.1492
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.8233 - mae: 0.5094 - val_loss: 0.1264 - val_mae: 0.2058
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.3987 - mae: 0.3360 - val_loss: 0.0934 - val_mae: 0.1272
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.2303 - mae: 0.1924 - val_loss: 0.0881 - val_mae: 0.1174
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.2157 - mae: 0.2003 - val_loss: 0.0889 - val_mae: 0.1186
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.4282 - mae: 0.3177 - val_loss: 0.0860 - val_mae: 0.1164
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.4303 - mae: 0.3818 - val_loss: 0.0871 - val_mae: 0.1351
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3244 - mae: 0.2938 - val_loss: 0.0857 - val_mae: 0.1162
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - loss: 0.3257 - mae: 0.2852 - val_loss: 0.0904 - val_mae: 0.1226
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.5793 - mae: 0.4167 - val_loss: 0.0867 - val_mae: 0.1172
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.2573 - mae: 0.2266 - val_loss: 0.0958 - val_mae: 0.1322
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.2246 - mae: 0.2124 - val_loss: 0.0883 - val_mae: 0.1167
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.3115 - mae: 0.2599 - val_loss: 0.1346 - val_mae: 0.2170
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.6877 - mae: 0.4997 - val_loss: 0.3821 - val_mae: 0.5083
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.2812 - mae: 0.2759 - val_loss: 0.0833 - val_mae: 0.1156
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.1871 - mae: 0.1783 - val_loss: 0.0850 - val_mae: 0.1133
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3369 - mae: 0.2434 - val_loss: 0.0879 - val_mae: 0.1169
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.4638 - mae: 0.4066 - val_loss: 0.0890 - val_mae: 0.1401
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2277 - mae: 0.2227 - val_loss: 0.0840 - val_mae: 0.1146
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.2731 - mae: 0.2281 - val_loss: 0.1160 - val_mae: 0.1785
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.4337 - mae: 0.3541 - val_loss: 0.0890 - val_mae: 0.1401
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.2605 - mae: 0.2508 - val_loss: 0.0845 - val_mae: 0.1137
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.2477 - mae: 0.2189 - val_loss: 0.0842 - val_mae: 0.1161
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.6653 - mae: 0.4242 - val_loss: 0.0866 - val_mae: 0.1158
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2602 - mae: 0.2355 - val_loss: 0.0850 - val_mae: 0.1137
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.1949 - mae: 0.1767 - val_loss: 0.0931 - val_mae: 0.1252
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.1784 - mae: 0.1687 - val_loss: 0.0978 - val_mae: 0.1363
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.3251 - mae: 0.2438 - val_loss: 0.0835 - val_mae: 0.1146
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.5383 - mae: 0.4263 - val_loss: 0.0914 - val_mae: 0.1457
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.2143 - mae: 0.2037 - val_loss: 0.0842 - val_mae: 0.1135
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2242 - mae: 0.2030 - val_loss: 0.0918 - val_mae: 0.1229
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.4166 - mae: 0.3055 - val_loss: 0.0843 - val_mae: 0.1144
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3246 - mae: 0.3094 - val_loss: 0.0831 - val_mae: 0.1176
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.2071 - mae: 0.2030 - val_loss: 0.0875 - val_mae: 0.1150
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3148 - mae: 0.2436 - val_loss: 0.0949 - val_mae: 0.1298
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.2737 - mae: 0.2694 - val_loss: 0.0842 - val_mae: 0.1258
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2963 - mae: 0.2469 - val_loss: 0.0851 - val_mae: 0.1123
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.2924 - mae: 0.2694 - val_loss: 0.0832 - val_mae: 0.1154
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4438 - mae: 0.3380 - val_loss: 0.0917 - val_mae: 0.1229
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2873 - mae: 0.2661 - val_loss: 0.0901 - val_mae: 0.1189
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.2170 - mae: 0.1990 - val_loss: 0.1033 - val_mae: 0.1508
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.2705 - mae: 0.2238 - val_loss: 0.0835 - val_mae: 0.1119
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.3988 - mae: 0.3266 - val_loss: 0.0836 - val_mae: 0.1236
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.2328 - mae: 0.2228 - val_loss: 0.0835 - val_mae: 0.1109
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.2071 - mae: 0.1840 - val_loss: 0.0881 - val_mae: 0.1142
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.3975 - mae: 0.2780 - val_loss: 0.0842 - val_mae: 0.1100
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.2521 - mae: 0.2566 - val_loss: 0.0823 - val_mae: 0.1133
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.1888 - mae: 0.1796 - val_loss: 0.1025 - val_mae: 0.1497
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.2509 - mae: 0.2021 - val_loss: 0.0850 - val_mae: 0.1095
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.4420 - mae: 0.3337 - val_loss: 0.0989 - val_mae: 0.1605
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.2650 - mae: 0.2619 - val_loss: 0.0968 - val_mae: 0.1564
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.1939 - mae: 0.1847 - val_loss: 0.0862 - val_mae: 0.1325
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2437 - mae: 0.1929 - val_loss: 0.0862 - val_mae: 0.1108
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.3922 - mae: 0.3159 - val_loss: 0.0999 - val_mae: 0.1434
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.3225 - mae: 0.2980 - val_loss: 0.0829 - val_mae: 0.1092
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.2004 - mae: 0.1887 - val_loss: 0.0962 - val_mae: 0.1343
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.2322 - mae: 0.1862 - val_loss: 0.0828 - val_mae: 0.1076
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.3741 - mae: 0.2987 - val_loss: 0.0892 - val_mae: 0.1404
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.3621 - mae: 0.3166 - val_loss: 0.0856 - val_mae: 0.1097
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.1944 - mae: 0.1824 - val_loss: 0.0843 - val_mae: 0.1076
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.1871 - mae: 0.1530 - val_loss: 0.0841 - val_mae: 0.1073
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.3533 - mae: 0.2527 - val_loss: 0.0816 - val_mae: 0.1138
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.2386 - mae: 0.2459 - val_loss: 0.0818 - val_mae: 0.1086
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.1909 - mae: 0.1809 - val_loss: 0.0830 - val_mae: 0.1062
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.2979 - mae: 0.2303 - val_loss: 0.0816 - val_mae: 0.1128
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.5321 - mae: 0.3908 - val_loss: 0.0820 - val_mae: 0.1167
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.1960 - mae: 0.1684 - val_loss: 0.0845 - val_mae: 0.1066
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.1671 - mae: 0.1492 - val_loss: 0.0883 - val_mae: 0.1140
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.1651 - mae: 0.1362 - val_loss: 0.0818 - val_mae: 0.1064
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3397 - mae: 0.2356 - val_loss: 0.0885 - val_mae: 0.1381
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.2867 - mae: 0.2976 - val_loss: 0.0821 - val_mae: 0.1081
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Entrenando modelo con 250 épocas
# Epoch 1/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 419ms/step - loss: 18.3780 - mae: 1.9131 - val_loss: 0.7750 - val_mae: 0.7762
# Epoch 2/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 1.6031 - mae: 0.8590 - val_loss: 0.2332 - val_mae: 0.3942
# Epoch 3/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.8518 - mae: 0.5359 - val_loss: 1.3857 - val_mae: 1.0935
# Epoch 4/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 1.3464 - mae: 0.9532 - val_loss: 0.0920 - val_mae: 0.1407
# Epoch 5/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.9133 - mae: 0.4236 - val_loss: 0.1772 - val_mae: 0.3176
# Epoch 6/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.8156 - mae: 0.5674 - val_loss: 0.1123 - val_mae: 0.1962
# Epoch 7/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.7755 - mae: 0.5333 - val_loss: 0.1042 - val_mae: 0.1617
# Epoch 8/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.7761 - mae: 0.5477 - val_loss: 0.0822 - val_mae: 0.1051
# Epoch 9/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.7334 - mae: 0.5051 - val_loss: 0.0796 - val_mae: 0.1004
# Epoch 10/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.7322 - mae: 0.5069 - val_loss: 0.0843 - val_mae: 0.1099
# Epoch 11/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.7265 - mae: 0.5250 - val_loss: 0.0783 - val_mae: 0.0973
# Epoch 12/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.6978 - mae: 0.4965 - val_loss: 0.0799 - val_mae: 0.1026
# Epoch 13/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.7299 - mae: 0.5266 - val_loss: 0.0785 - val_mae: 0.0979
# Epoch 14/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.6658 - mae: 0.4626 - val_loss: 0.0861 - val_mae: 0.1293
# Epoch 15/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.6359 - mae: 0.4436 - val_loss: 0.0896 - val_mae: 0.1197
# Epoch 16/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.9199 - mae: 0.6530 - val_loss: 0.0823 - val_mae: 0.1052
# Epoch 17/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.7974 - mae: 0.4221 - val_loss: 0.0785 - val_mae: 0.1023
# Epoch 18/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.7046 - mae: 0.4784 - val_loss: 0.0843 - val_mae: 0.1122
# Epoch 19/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.7847 - mae: 0.5972 - val_loss: 0.1167 - val_mae: 0.1922
# Epoch 20/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.6721 - mae: 0.4568 - val_loss: 0.0957 - val_mae: 0.1528
# Epoch 21/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.6066 - mae: 0.4475 - val_loss: 0.0877 - val_mae: 0.1090
# Epoch 22/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.8329 - mae: 0.6118 - val_loss: 0.0820 - val_mae: 0.1055
# Epoch 23/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.6988 - mae: 0.4001 - val_loss: 0.0818 - val_mae: 0.1133
# Epoch 24/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.5880 - mae: 0.4392 - val_loss: 0.0860 - val_mae: 0.1322
# Epoch 25/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - loss: 0.6596 - mae: 0.5068 - val_loss: 0.1187 - val_mae: 0.1894
# Epoch 26/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.5573 - mae: 0.4359 - val_loss: 0.0821 - val_mae: 0.1159
# Epoch 27/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.5930 - mae: 0.4402 - val_loss: 0.0868 - val_mae: 0.1343
# Epoch 28/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.5323 - mae: 0.4215 - val_loss: 0.0822 - val_mae: 0.1181
# Epoch 29/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.7325 - mae: 0.5289 - val_loss: 0.1496 - val_mae: 0.2635
# Epoch 30/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.7945 - mae: 0.4603 - val_loss: 0.0843 - val_mae: 0.1265
# Epoch 31/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.5450 - mae: 0.4342 - val_loss: 0.0805 - val_mae: 0.1071
# Epoch 32/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.7421 - mae: 0.5635 - val_loss: 0.0914 - val_mae: 0.1172
# Epoch 33/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5647 - mae: 0.3893 - val_loss: 0.0818 - val_mae: 0.1172
# Epoch 34/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.4322 - mae: 0.3467 - val_loss: 0.0815 - val_mae: 0.1109
# Epoch 35/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 1.5873 - mae: 0.8888 - val_loss: 0.6896 - val_mae: 0.7544
# Epoch 36/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.9753 - mae: 0.6431 - val_loss: 0.0947 - val_mae: 0.1311
# Epoch 37/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.8341 - mae: 0.4497 - val_loss: 0.1108 - val_mae: 0.1828
# Epoch 38/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.7257 - mae: 0.5410 - val_loss: 1.7930 - val_mae: 1.2616
# Epoch 39/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 2.1919 - mae: 1.2968 - val_loss: 0.0813 - val_mae: 0.1150
# Epoch 40/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.7304 - mae: 0.3941 - val_loss: 0.0827 - val_mae: 0.1220
# Epoch 41/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.5766 - mae: 0.3980 - val_loss: 0.2793 - val_mae: 0.2755
# Epoch 42/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 3.8988 - mae: 1.5975 - val_loss: 0.3959 - val_mae: 0.5419
# Epoch 43/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.9313 - mae: 0.5646 - val_loss: 0.1011 - val_mae: 0.1473
# Epoch 44/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.8737 - mae: 0.4573 - val_loss: 0.0943 - val_mae: 0.1254
# Epoch 45/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.8357 - mae: 0.4583 - val_loss: 0.1058 - val_mae: 0.1663
# Epoch 46/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.8237 - mae: 0.4959 - val_loss: 0.2497 - val_mae: 0.4054
# Epoch 47/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.8561 - mae: 0.5774 - val_loss: 0.0865 - val_mae: 0.1042
# Epoch 48/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.7958 - mae: 0.4643 - val_loss: 0.0809 - val_mae: 0.1099
# Epoch 49/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.7673 - mae: 0.4670 - val_loss: 0.1596 - val_mae: 0.2822
# Epoch 50/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.7613 - mae: 0.5884 - val_loss: 0.0843 - val_mae: 0.1121
# Epoch 51/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.8402 - mae: 0.6681 - val_loss: 0.1033 - val_mae: 0.1530
# Epoch 52/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.6500 - mae: 0.4546 - val_loss: 0.0849 - val_mae: 0.1293
# Epoch 53/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.5235 - mae: 0.4111 - val_loss: 0.0812 - val_mae: 0.1100
# Epoch 54/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.8171 - mae: 0.6100 - val_loss: 0.0839 - val_mae: 0.1172
# Epoch 55/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.5641 - mae: 0.3772 - val_loss: 0.0839 - val_mae: 0.1183
# Epoch 56/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.4531 - mae: 0.3527 - val_loss: 0.0854 - val_mae: 0.1166
# Epoch 57/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.6186 - mae: 0.4513 - val_loss: 0.5193 - val_mae: 0.6355
# Epoch 58/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.8221 - mae: 0.5586 - val_loss: 0.1170 - val_mae: 0.1890
# Epoch 59/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.4721 - mae: 0.4146 - val_loss: 0.0810 - val_mae: 0.1136
# Epoch 60/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.8793 - mae: 0.6139 - val_loss: 0.0946 - val_mae: 0.1260
# Epoch 61/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.6197 - mae: 0.3838 - val_loss: 0.0845 - val_mae: 0.1277
# Epoch 62/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.4188 - mae: 0.3484 - val_loss: 0.0860 - val_mae: 0.1317
# Epoch 63/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.4331 - mae: 0.3530 - val_loss: 0.0833 - val_mae: 0.1237
# Epoch 64/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.7945 - mae: 0.5887 - val_loss: 0.0850 - val_mae: 0.1244
# Epoch 65/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.4219 - mae: 0.3363 - val_loss: 0.0859 - val_mae: 0.1218
# Epoch 66/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.3353 - mae: 0.2932 - val_loss: 0.0859 - val_mae: 0.1270
# Epoch 67/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.6468 - mae: 0.4375 - val_loss: 0.0936 - val_mae: 0.1265
# Epoch 68/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.7080 - mae: 0.3898 - val_loss: 0.0965 - val_mae: 0.1559
# Epoch 69/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.4416 - mae: 0.4006 - val_loss: 0.0866 - val_mae: 0.1193
# Epoch 70/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.7033 - mae: 0.5170 - val_loss: 0.0854 - val_mae: 0.1268
# Epoch 71/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3917 - mae: 0.3308 - val_loss: 0.0875 - val_mae: 0.1212
# Epoch 72/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.3019 - mae: 0.2731 - val_loss: 0.0921 - val_mae: 0.1278
# Epoch 73/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.6728 - mae: 0.4390 - val_loss: 0.1509 - val_mae: 0.2502
# Epoch 74/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.6282 - mae: 0.3899 - val_loss: 0.0985 - val_mae: 0.1600
# Epoch 75/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3269 - mae: 0.3195 - val_loss: 0.0862 - val_mae: 0.1188
# Epoch 76/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.5445 - mae: 0.4145 - val_loss: 0.1054 - val_mae: 0.1539
# Epoch 77/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.3079 - mae: 0.2914 - val_loss: 0.0844 - val_mae: 0.1197
# Epoch 78/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.2016 - mae: 0.2036 - val_loss: 0.0848 - val_mae: 0.1235
# Epoch 79/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.9489 - mae: 0.5003 - val_loss: 0.4477 - val_mae: 0.5790
# Epoch 80/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.9120 - mae: 0.5449 - val_loss: 0.1022 - val_mae: 0.1467
# Epoch 81/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.6587 - mae: 0.4132 - val_loss: 0.0865 - val_mae: 0.1336
# Epoch 82/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.4544 - mae: 0.3862 - val_loss: 0.0873 - val_mae: 0.1356
# Epoch 83/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - loss: 0.4323 - mae: 0.3950 - val_loss: 0.0895 - val_mae: 0.1193
# Epoch 84/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.6559 - mae: 0.5125 - val_loss: 0.0868 - val_mae: 0.1344
# Epoch 85/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.3192 - mae: 0.3007 - val_loss: 0.0843 - val_mae: 0.1259
# Epoch 86/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2992 - mae: 0.2770 - val_loss: 0.0838 - val_mae: 0.1220
# Epoch 87/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.7409 - mae: 0.4918 - val_loss: 0.0855 - val_mae: 0.1181
# Epoch 88/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.3104 - mae: 0.2819 - val_loss: 0.0845 - val_mae: 0.1179
# Epoch 89/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.2607 - mae: 0.2448 - val_loss: 0.0968 - val_mae: 0.1339
# Epoch 90/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.5124 - mae: 0.3785 - val_loss: 0.1037 - val_mae: 0.1490
# Epoch 91/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.3128 - mae: 0.3002 - val_loss: 0.0838 - val_mae: 0.1187
# Epoch 92/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.2933 - mae: 0.2740 - val_loss: 0.0890 - val_mae: 0.1206
# Epoch 93/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.6317 - mae: 0.4355 - val_loss: 0.0845 - val_mae: 0.1201
# Epoch 94/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.2811 - mae: 0.2596 - val_loss: 0.0845 - val_mae: 0.1176
# Epoch 95/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.2242 - mae: 0.2184 - val_loss: 0.1017 - val_mae: 0.1447
# Epoch 96/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3969 - mae: 0.3080 - val_loss: 0.0939 - val_mae: 0.1279
# Epoch 97/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.3184 - mae: 0.3138 - val_loss: 0.0860 - val_mae: 0.1302
# Epoch 98/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.4111 - mae: 0.3322 - val_loss: 0.0857 - val_mae: 0.1287
# Epoch 99/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - loss: 0.2848 - mae: 0.2777 - val_loss: 0.0858 - val_mae: 0.1214
# Epoch 100/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.2907 - mae: 0.2591 - val_loss: 0.0871 - val_mae: 0.1217
# Epoch 101/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.4094 - mae: 0.3314 - val_loss: 0.0854 - val_mae: 0.1265
# Epoch 102/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.2945 - mae: 0.2817 - val_loss: 0.0855 - val_mae: 0.1224
# Epoch 103/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.3433 - mae: 0.2824 - val_loss: 0.0906 - val_mae: 0.1251
# Epoch 104/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.3395 - mae: 0.3100 - val_loss: 0.1108 - val_mae: 0.1660
# Epoch 105/250
# ...
# Epoch 117/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.4148 - mae: 0.2938 - val_loss: 0.0848 - val_mae: 0.1184
# Epoch 118/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.2478 - mae: 0.2382 - val_loss: 0.0878 - val_mae: 0.1181
# Epoch 119/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.1958 - mae: 0.1906 - val_loss: 0.1058 - val_mae: 0.1555
# Epoch 120/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.3759 - mae: 0.2698 - val_loss: 0.0963 - val_mae: 0.1341
# Epoch 121/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.2514 - mae: 0.2584 - val_loss: 0.0839 - val_mae: 0.1210
# Epoch 122/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.2265 - mae: 0.2105 - val_loss: 0.0845 - val_mae: 0.1240
# Epoch 123/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.6850 - mae: 0.4139 - val_loss: 0.0886 - val_mae: 0.1387
# Epoch 124/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.2503 - mae: 0.2346 - val_loss: 0.0919 - val_mae: 0.1246
# Epoch 125/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.1901 - mae: 0.1815 - val_loss: 0.1079 - val_mae: 0.1607
# Epoch 126/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - loss: 0.1815 - mae: 0.1694 - val_loss: 0.0949 - val_mae: 0.1305
# Epoch 127/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.5512 - mae: 0.3477 - val_loss: 0.0844 - val_mae: 0.1255
# Epoch 128/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.2345 - mae: 0.2220 - val_loss: 0.0873 - val_mae: 0.1160
# Epoch 129/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.1713 - mae: 0.1664 - val_loss: 0.0902 - val_mae: 0.1202
# Epoch 130/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.1709 - mae: 0.1554 - val_loss: 0.0930 - val_mae: 0.1266
# Epoch 131/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.6836 - mae: 0.3981 - val_loss: 0.0830 - val_mae: 0.1172
# Epoch 132/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.3816 - mae: 0.2744 - val_loss: 0.0856 - val_mae: 0.1144
# Epoch 133/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.2146 - mae: 0.2247 - val_loss: 0.0841 - val_mae: 0.1150
# Epoch 134/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.2644 - mae: 0.2382 - val_loss: 0.0846 - val_mae: 0.1164
# Epoch 135/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.4454 - mae: 0.3478 - val_loss: 0.0851 - val_mae: 0.1153
# Epoch 136/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.2130 - mae: 0.2128 - val_loss: 0.1130 - val_mae: 0.1727
# Epoch 137/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.2270 - mae: 0.2130 - val_loss: 0.1040 - val_mae: 0.1517
# Epoch 138/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.5135 - mae: 0.3540 - val_loss: 0.0887 - val_mae: 0.1392
# Epoch 139/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.2073 - mae: 0.1976 - val_loss: 0.0868 - val_mae: 0.1147
# Epoch 140/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.1636 - mae: 0.1468 - val_loss: 0.0940 - val_mae: 0.1280
# Epoch 141/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.1519 - mae: 0.1295 - val_loss: 0.0957 - val_mae: 0.1320
# Epoch 142/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.1513 - mae: 0.1273 - val_loss: 0.0888 - val_mae: 0.1163
# Epoch 143/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.2154 - mae: 0.2031 - val_loss: 0.0852 - val_mae: 0.1110
# Epoch 144/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.4864 - mae: 0.3304 - val_loss: 0.0835 - val_mae: 0.1125
# Epoch 145/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.1772 - mae: 0.1671 - val_loss: 0.0859 - val_mae: 0.1119
# Epoch 146/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.2125 - mae: 0.2009 - val_loss: 0.0846 - val_mae: 0.1107
# Epoch 147/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.4379 - mae: 0.3186 - val_loss: 0.0832 - val_mae: 0.1126
# Epoch 148/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.2144 - mae: 0.2002 - val_loss: 0.0844 - val_mae: 0.1109
# Epoch 149/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.3288 - mae: 0.2780 - val_loss: 0.0827 - val_mae: 0.1172
# Epoch 150/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - loss: 0.2979 - mae: 0.2588 - val_loss: 0.0839 - val_mae: 0.1119
# Epoch 151/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.2182 - mae: 0.2061 - val_loss: 0.0860 - val_mae: 0.1122
# Epoch 152/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.3057 - mae: 0.2660 - val_loss: 0.0827 - val_mae: 0.1167
# Epoch 153/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.2228 - mae: 0.2094 - val_loss: 0.0830 - val_mae: 0.1128
# Epoch 154/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.2908 - mae: 0.2573 - val_loss: 0.0828 - val_mae: 0.1143
# Epoch 155/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.2146 - mae: 0.2026 - val_loss: 0.0849 - val_mae: 0.1115
# Epoch 156/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.2966 - mae: 0.2620 - val_loss: 0.0827 - val_mae: 0.1151
# Epoch 157/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.2344 - mae: 0.2198 - val_loss: 0.0826 - val_mae: 0.1150
# Epoch 158/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.3097 - mae: 0.2689 - val_loss: 0.0827 - val_mae: 0.1142
# Epoch 159/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2374 - mae: 0.2224 - val_loss: 0.0830 - val_mae: 0.1129
# Epoch 160/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.2393 - mae: 0.2229 - val_loss: 0.0833 - val_mae: 0.1123
# Epoch 161/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - loss: 0.2042 - mae: 0.1907 - val_loss: 0.0831 - val_mae: 0.1117
# Epoch 162/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 0.3922 - mae: 0.3051 - val_loss: 0.0827 - val_mae: 0.1187
# Epoch 163/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.2354 - mae: 0.2178 - val_loss: 0.0832 - val_mae: 0.1131
# Epoch 164/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.1705 - mae: 0.1550 - val_loss: 0.0875 - val_mae: 0.1138
# Epoch 165/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - loss: 0.2329 - mae: 0.2116 - val_loss: 0.0855 - val_mae: 0.1303
# Epoch 166/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.5430 - mae: 0.3463 - val_loss: 0.0837 - val_mae: 0.1122
# Epoch 167/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.2151 - mae: 0.2150 - val_loss: 0.0831 - val_mae: 0.1157
# Epoch 168/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.5569 - mae: 0.3718 - val_loss: 0.0902 - val_mae: 0.1200
# Epoch 169/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.2357 - mae: 0.2246 - val_loss: 0.0847 - val_mae: 0.1125
# Epoch 170/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.1834 - mae: 0.1793 - val_loss: 0.0889 - val_mae: 0.1164
# Epoch 171/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.2521 - mae: 0.2067 - val_loss: 0.0861 - val_mae: 0.1133
# Epoch 172/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.4779 - mae: 0.3611 - val_loss: 0.0847 - val_mae: 0.1276
# Epoch 173/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.2071 - mae: 0.1989 - val_loss: 0.0846 - val_mae: 0.1111
# Epoch 174/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.1743 - mae: 0.1630 - val_loss: 0.0917 - val_mae: 0.1221
# Epoch 175/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.3133 - mae: 0.2338 - val_loss: 0.0867 - val_mae: 0.1125
# Epoch 176/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.2693 - mae: 0.2591 - val_loss: 0.0854 - val_mae: 0.1301
# Epoch 177/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.2079 - mae: 0.1993 - val_loss: 0.0833 - val_mae: 0.1103
# Epoch 178/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.2148 - mae: 0.1863 - val_loss: 0.0876 - val_mae: 0.1136
# Epoch 179/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.4153 - mae: 0.2978 - val_loss: 0.0828 - val_mae: 0.1114
# Epoch 180/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.2468 - mae: 0.2404 - val_loss: 0.0822 - val_mae: 0.1158
# Epoch 181/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.1797 - mae: 0.1681 - val_loss: 0.0997 - val_mae: 0.1434
# Epoch 182/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.1921 - mae: 0.1637 - val_loss: 0.1003 - val_mae: 0.1453
# Epoch 183/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.2406 - mae: 0.1970 - val_loss: 0.0839 - val_mae: 0.1249
# Epoch 184/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.4451 - mae: 0.3262 - val_loss: 0.0999 - val_mae: 0.1623
# Epoch 185/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.2554 - mae: 0.2478 - val_loss: 0.0896 - val_mae: 0.1176
# Epoch 186/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.1725 - mae: 0.1573 - val_loss: 0.0958 - val_mae: 0.1338
# Epoch 187/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.1608 - mae: 0.1331 - val_loss: 0.0941 - val_mae: 0.1294
# Epoch 188/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.1759 - mae: 0.1408 - val_loss: 0.0849 - val_mae: 0.1079
# Epoch 189/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.5268 - mae: 0.3295 - val_loss: 0.1097 - val_mae: 0.1788
# Epoch 190/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.2027 - mae: 0.1885 - val_loss: 0.0840 - val_mae: 0.1053
# Epoch 191/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.1621 - mae: 0.1450 - val_loss: 0.0853 - val_mae: 0.1070
# Epoch 192/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.1509 - mae: 0.1280 - val_loss: 0.0903 - val_mae: 0.1194
# Epoch 193/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.1809 - mae: 0.1711 - val_loss: 0.1012 - val_mae: 0.1501
# Epoch 194/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.3260 - mae: 0.2781 - val_loss: 0.0811 - val_mae: 0.1055
# Epoch 195/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.2399 - mae: 0.2212 - val_loss: 0.0838 - val_mae: 0.1043
# Epoch 196/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.1598 - mae: 0.1405 - val_loss: 0.0898 - val_mae: 0.1182
# Epoch 197/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.1782 - mae: 0.1675 - val_loss: 0.0924 - val_mae: 0.1260
# Epoch 198/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3615 - mae: 0.2918 - val_loss: 0.0834 - val_mae: 0.1033
# Epoch 199/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - loss: 0.2968 - mae: 0.2556 - val_loss: 0.0830 - val_mae: 0.1028
# Epoch 200/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 0.1576 - mae: 0.1360 - val_loss: 0.0879 - val_mae: 0.1129
# Epoch 201/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.1528 - mae: 0.1286 - val_loss: 0.0909 - val_mae: 0.1218
# Epoch 202/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.2505 - mae: 0.2216 - val_loss: 0.0945 - val_mae: 0.1330
# Epoch 203/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.5584 - mae: 0.3492 - val_loss: 0.0803 - val_mae: 0.1075
# Epoch 204/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.1889 - mae: 0.1867 - val_loss: 0.0803 - val_mae: 0.1035
# Epoch 205/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.2084 - mae: 0.1908 - val_loss: 0.0803 - val_mae: 0.1110
# Epoch 206/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.6040 - mae: 0.3869 - val_loss: 0.0993 - val_mae: 0.1605
# Epoch 207/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.2167 - mae: 0.2086 - val_loss: 0.0820 - val_mae: 0.0991
# Epoch 208/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.1668 - mae: 0.1492 - val_loss: 0.0887 - val_mae: 0.1159
# Epoch 209/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.1527 - mae: 0.1292 - val_loss: 0.0893 - val_mae: 0.1185
# Epoch 210/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.1477 - mae: 0.1221 - val_loss: 0.0835 - val_mae: 0.1009
# Epoch 211/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.1499 - mae: 0.1278 - val_loss: 0.1018 - val_mae: 0.1604
# Epoch 212/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.2910 - mae: 0.2586 - val_loss: 0.0806 - val_mae: 0.0961
# Epoch 213/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.3274 - mae: 0.2723 - val_loss: 0.0818 - val_mae: 0.0976
# Epoch 214/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.1649 - mae: 0.1467 - val_loss: 0.0796 - val_mae: 0.0944
# Epoch 215/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.2416 - mae: 0.1840 - val_loss: 0.0870 - val_mae: 0.1336
# Epoch 216/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.4973 - mae: 0.3812 - val_loss: 0.0849 - val_mae: 0.1281
# Epoch 217/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.2163 - mae: 0.2099 - val_loss: 0.0790 - val_mae: 0.1016
# Epoch 218/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.2195 - mae: 0.1949 - val_loss: 0.0858 - val_mae: 0.1305
# Epoch 219/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.3182 - mae: 0.2588 - val_loss: 0.1092 - val_mae: 0.1775
# Epoch 220/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.2474 - mae: 0.2362 - val_loss: 0.0790 - val_mae: 0.0929
# Epoch 221/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.1717 - mae: 0.1550 - val_loss: 0.0812 - val_mae: 0.0951
# Epoch 222/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.1705 - mae: 0.1364 - val_loss: 0.0830 - val_mae: 0.1017
# Epoch 223/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.3780 - mae: 0.2535 - val_loss: 0.0979 - val_mae: 0.1560
# Epoch 224/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.2835 - mae: 0.2744 - val_loss: 0.0805 - val_mae: 0.1137
# Epoch 225/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.2265 - mae: 0.2036 - val_loss: 0.0904 - val_mae: 0.1411
# Epoch 226/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.2065 - mae: 0.1792 - val_loss: 0.0888 - val_mae: 0.1373
# Epoch 227/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.2710 - mae: 0.2182 - val_loss: 0.0873 - val_mae: 0.1335
# Epoch 228/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.2660 - mae: 0.2414 - val_loss: 0.0801 - val_mae: 0.1125
# Epoch 229/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.1658 - mae: 0.1464 - val_loss: 0.0761 - val_mae: 0.0898
# Epoch 230/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.1505 - mae: 0.1154 - val_loss: 0.0756 - val_mae: 0.0823
# Epoch 231/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.1473 - mae: 0.1082 - val_loss: 0.0831 - val_mae: 0.1199
# Epoch 232/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.1950 - mae: 0.1628 - val_loss: 0.1405 - val_mae: 0.2281
# Epoch 233/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.5660 - mae: 0.4159 - val_loss: 0.0847 - val_mae: 0.1250
# Epoch 234/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.2311 - mae: 0.2227 - val_loss: 0.0786 - val_mae: 0.0914
# Epoch 235/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.1625 - mae: 0.1398 - val_loss: 0.0758 - val_mae: 0.0862
# Epoch 236/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.1487 - mae: 0.1181 - val_loss: 0.0789 - val_mae: 0.0922
# Epoch 237/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.1438 - mae: 0.1076 - val_loss: 0.0806 - val_mae: 0.0995
# Epoch 238/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.1526 - mae: 0.1100 - val_loss: 0.0752 - val_mae: 0.0869
# Epoch 239/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.3597 - mae: 0.2484 - val_loss: 0.1362 - val_mae: 0.2214
# Epoch 240/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - loss: 0.2136 - mae: 0.2306 - val_loss: 0.0794 - val_mae: 0.1096
# Epoch 241/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.1522 - mae: 0.1264 - val_loss: 0.0963 - val_mae: 0.1567
# Epoch 242/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.1477 - mae: 0.1157 - val_loss: 0.0758 - val_mae: 0.0811
# Epoch 243/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.1538 - mae: 0.1287 - val_loss: 0.0894 - val_mae: 0.1333
# Epoch 244/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.3078 - mae: 0.2587 - val_loss: 0.0947 - val_mae: 0.1501
# Epoch 245/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.3178 - mae: 0.2659 - val_loss: 0.0794 - val_mae: 0.0931
# Epoch 246/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.1575 - mae: 0.1318 - val_loss: 0.0831 - val_mae: 0.1084
# Epoch 247/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.2446 - mae: 0.2099 - val_loss: 0.1345 - val_mae: 0.2467
# Epoch 248/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.4712 - mae: 0.3450 - val_loss: 0.0761 - val_mae: 0.0950
# Epoch 249/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.1710 - mae: 0.1537 - val_loss: 0.0756 - val_mae: 0.0802
# Epoch 250/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.1552 - mae: 0.1305 - val_loss: 0.0743 - val_mae: 0.0821
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
for i, history in enumerate(histories):
    final_loss = history.history['loss'][-1]
    print(f"Modelo {i+1} con {eplist[i]} épocas terminó con pérdida: {final_loss:.5f}")

# %%
plt.figure(figsize=(10,6))
for lr, history in loss_histories.items():
    plt.plot(history['loss'], label=f'loss lr={lr}')
    plt.plot(history['val_loss'], label=f'val_loss lr={lr}')
plt.axis([0, epochs, -0.01, 1.5])
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('Comparación de Validation Loss para distintos Learning Rates')
plt.legend()
plt.show()

# %%
y_pred = model1.predict(inputsmodel) #Predecimos datos de Potencial en base a los datos de testing
plt.plot(df.V,y_pred,'o')
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
datos = model1.predict_on_batch(inputsmodel) #Estudiar esto
aa= datos.tolist()
lista = []
for i in range(len(aa)):
    lista.append(aa[i][0])
df1 = pd.DataFrame()
df1['predicted'] = lista
df1
# Out:
#      predicted
# 0     4.684839
# 1     4.724708
# 2     4.495740
# 3     4.263618
# 4     4.134248
# ..         ...
# 724   0.309832
# 725   0.335315
# 726   0.370199
# 727   0.400756
# 728   0.434960
#
# [729 rows x 1 columns]

# %%
#np.save('training_results_lr_'+str(lr)+'_epochs_'+str(epochs)+'_vsplit'+str(pv)+'.npy',np.array([history['val_loss'],history['loss']]))
#np.save('training_predictions_lr_'+str(lr)+'_epochs_'+str(epochs)+'_vsplit'+str(pv)+'.npy',np.array([df['V'],lista]))

#np.save('TrainFOR_'+'ep:'+str(epochs)+'.npy', np.array([history['val_loss'],history['loss']]))
#np.save('ResultsFOR_'+'ep:'+str(epochs)+'.npy', np.array([df['V'],lista]))

#test = np.load('test.npy')
#plt.plot(test[0,:])
#plt.plot(test[1,:])
#plt.axis([0, ep, -0.01, 1.5])
#plt.xlabel('Epoch')
#plt.ylabel('Validation Loss')
#plt.title('Comparación de Validation Loss para distintos Learning Rates')
#plt.legend()

# %%
plt.plot(df['V'], df1['predicted'],'o')
plt.plot(df['V'], df['V'])
plt.axis([-0.1,5,-0.1,5])
# Out:
# (-0.1, 5.0, -0.1, 5.0)

# %% [markdown]
# # Recursos de utilidad
# https://wandb.ai/ayush-thakur/dl-question-bank/reports/Input-Keras-Layer-Explanation-With-Code-Samples--VmlldzoyMDIzMDU#:~:text=a%20certain%20way.-,What%20Is%20Dim%20In%20A%20Keras%20Layer%3F,tensor%20like%20(3%2C).

# %% [markdown]
# # Que son las PINNs?
# $\textit{Physics Informed neural networks}$ son redes neuronales que incluyen leyes fisicas para resolver un problema fisico, en la forma de ecuaciones diferenciales parciales adicionales al problema supervisado original.
# En las PINNs se combinan el efecto de adherirse a una ecuacion fisica asi como tambien los conocimientos familiares de machine learning
#
# ## Como se usa una PINN?
# Hacer uso de una PINN incluye anadir un residual en terminos de perdida
#
# ## Ecuacion de Burgers
# Consideramos la ecuacion de Burgers como ejemplo. En una dimension, la ecuacion de Burgers junto con la condicion de frontera de Dirichlet es:
#
# \begin{split}
#   u_t + uu_x - (0.001/\pi)u_{xx}=0, \\
#   x \in [-1,1],t\in [0,1], \\
#   u(0,x)=-\sin(\pi x), \\
#   u(t,-1)=u(t,1)=0
# \end{split}

# %% [markdown]
# Definimos $f(t,x)$ como:
# $$f:= u_t+u_x-(0.01/\pi)u_{xx} $$
#
# Luego se aproxima $u(x,t)$ con una red neuronal profunda. Los parametros compartidos entre $u(t,x)$ y $f(t,x)$ se pueden aprender minimizando la perdida de error de minimos cuadrados:
#
# \begin{split}
#     MSE=MSE_u+MSE_f, \\
#     MSE_u = {1\over{N_u}}\sum_{i=1}^{N_u}{|u(t_{iu},x_{iu})-u_i|^2}, \\
#     MSE_f={1\over{N_f}}\sum_{i=1}^{N_f}{|f(t_{if},x_{if})|^2}
# \end{split}
#
# el loss $MSE_u$ corresponde al data inial y a las condiciones de frontera iniciales, mientras que $MSE_f$ refuerza la estructura impuesta por la ecuacion de Burgers en un set finito de punto de colocacion, esto actua como un termino residual.
# Los puntos t,x junto con la u denotan el training data inicial y de frontera en $u(t,x)$. Los puntos t,x con f especifican los puntos de colocacion para $f(t,x)$

# %% [markdown]
# # WORKFLOW
# La funcion morse tiene una forma $$D_O[1-\exp^{-\alpha_O(r_O -r_{eq_O})}]^2$$ para el enlace del oxigeno, y una forma $$D_S[1-\exp^{-\alpha_S(r_S -r_{eq_S})}]^2$$ para el enlace del azufre.

# %% [markdown]
# La forma de la ecuacion a agregar a la funcion perdida personalizada es del tipo: $$\underbrace{(\hat{y_i}-y_i)^2}_{\text{MSE}} + \underbrace{(\hat{y_i}-V(r_O,r_S))^2}_{\text{PINN MSE}}$$

# %% [markdown]
# Podemos hacer una interpolacion o una regresion unidimensional a una de las funciones morse
# Esto es funcion morse + ruido
# Morse 2-D
